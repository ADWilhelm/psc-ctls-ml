# %% [markdown]
# # How many cells are identified?
# This notebook contains code to check the results of the Identification pileline.

# %%
import pickle
import pandas as pd

# %% [markdown]
# ## Prepare data

# %%
# load dictionary
with open('data_RO1/dict_all_cells_v2.pkl', 'rb') as f:
    name_to_CID_dict = pickle.load(f)
    f.close()
    
# add empty dictionary entry for cells without an etl or htl
name_to_CID_dict['none'] = 0

# load dataframe
with open('data_RO1/df_all_ctls.pkl', 'rb') as f:
    df_all_ctls = pickle.load(f)
    
# ETLs: transform entries where multiple materials are separated by a ";" into lists
for index, _ in df_all_ctls.iterrows():
    i = 0
    while i < len(df_all_ctls.at[index, "etl"]):
        if ";" in df_all_ctls.at[index, "etl"][i]:
            elements = df_all_ctls.at[index, "etl"][i].split(";")
            df_all_ctls.at[index, "etl"] = df_all_ctls.at[index, "etl"][:i] + elements + df_all_ctls.at[index, "etl"][i+1:]
        i += 1
        
# HTLs: transform entries where multiple materials are separated by a ";" into lists
for index, _ in df_all_ctls.iterrows():
    i = 0
    while i < len(df_all_ctls.at[index, "htl"]):
        if ";" in df_all_ctls.at[index, "htl"][i]:
            elements = df_all_ctls.at[index, "htl"][i].split(";")
            df_all_ctls.at[index, "htl"] = df_all_ctls.at[index, "htl"][:i] + elements + df_all_ctls.at[index, "htl"][i+1:]
        i += 1

# %% [markdown]
# ## Combine dictionary info with data

# %%
# Create a DataFrame from the dictionary
df_new = pd.DataFrame(list(name_to_CID_dict.items()), columns=['Material', 'CID'])

# Create the 'etl' and 'htl' columns
df_new['etl'] = df_new['Material'].apply(lambda x: df_all_ctls[df_all_ctls['etl'].apply(lambda y: x in y)].index.tolist())
df_new['htl'] = df_new['Material'].apply(lambda x: df_all_ctls[df_all_ctls['htl'].apply(lambda y: x in y)].index.tolist())

# %%
# Count how many ETLs are identified
etl_identified = []
etl_count = 0

for index, row in df_all_ctls.iterrows():
    num_etl_materials = len(row['etl'])
    current_num = 0
    for material in row['etl']:
        material = str.strip(material)
        if pd.isna(df_new.loc[df_new['Material'] == material, 'CID'].values[0]):
            break # not identified
        else:
            current_num = current_num + 1 # another element identified
    if current_num == num_etl_materials:
        etl_count = etl_count + 1
        etl_identified.append(True)
    else:
        etl_identified.append(False)

# Count how many HTLs are identified
htl_count = 0
htl_identified = []

for index, row in df_all_ctls.iterrows():
    num_etl_materials = len(row['htl'])
    current_num = 0
    for material in row['htl']:
        material = str.strip(material)
        if pd.isna(df_new.loc[df_new['Material'] == material, 'CID'].values[0]):
            break
        else:
            current_num = current_num + 1
    if current_num == num_etl_materials:
        htl_count = htl_count + 1
        htl_identified.append(True)
    else:
        htl_identified.append(False)
        
# add identification to materials dataframe
df_all_ctls['etls_identified'] = etl_identified
df_all_ctls['htls_identified'] = htl_identified

# create a column stating whether both CTLs were identified
df_all_ctls['both_identified'] = df_all_ctls['etls_identified'] & df_all_ctls['htls_identified']

# %%
# ETL: resulting count of identified entries
print(f"{etl_count} entries have an identified ETL.")
print(f"Of these, {len(df_new.at[2449, 'etl'])} entries use no ETL material.")

# HTL: resulting count of identified entries
print(f"{htl_count} entries have an identified HTL.")
print(f"Of these, {len(df_new.at[2449, 'htl'])} entries use no HTL material.")

# Both: resulting count of identified entries
print(f"Both CTLs are identified for {df_all_ctls['both_identified'].sum()} cells.")
# how many cells have no CTL at all? (no HTL, no ETL)
print(f"Of these, {len(list(set(df_new.at[2449, 'htl']) & set(df_new.at[2449, 'etl'])))} cells have neither ETL nor HTL.")
# Out:
# 41090 entries have an identified ETL.
# Of these, 281 entries use no ETL material.
# 39647 entries have an identified HTL.
# Of these, 2626 entries use no HTL material.
# Both CTLs are identified for 37849 cells.
# Of these, 31 cells have neither ETL nor HTL.

# %%
# save into pickles folder
with open('data_RO1/df_all_ctls_identified_v2.pkl', 'wb') as f:
    pickle.dump(df_all_ctls, f)

# %%
# save as excel
df_all_ctls.to_excel('excel_tables/all_cells_identification_info.xlsx', sheet_name='All_cells')

# %%
for entry in name_to_CID_dict:
    if name_to_CID_dict[entry]:
        print(f"{entry}:{name_to_CID_dict[entry]}")
# Out:
# TiO2-c:26042
# bis-C60:53384373
# C60MC12:53384414
# Polyacrylonitrile:7855
# EPA:446284
# MgO-c:14792
# CT2:9547904
# X25:60210955
# Boron subphthalocyanine chloride:11826144
# IT-M:145710360
# LiF:224478
# V1056:2761560
# PTT:5462314
# ME1:10250490
# tert-CuBuPc:71311255
# ZrO2:62395
# PVP:6917
# TaTm:11113597
# V1102:2735154
# Q198:95377
# Cu:23978
# Cu2O:10313194
# IDIC:132575341
# IEICO-4F:139034750
# M109:2734487
# Au-nw:23985
# BaSnO3-nw:13981640
# CuP:16214778
# Polystyrene:7501
# Ba(OH)2:6093286
# TOPO:65577
# Co3O4:11651651
# SQ2:863054
# N719:71310680
# DTBT:396294
# JY6:165619050
# YK1:155883041
# CuSCN:11029823
# rGO:TiO2-nanofibrse:26042
# PCBM-60:53384373
# TZ3:165416455
# CdS:16750131
# NiO:938
# DTAB:14249
# SY2:42601398
# SM:23951
# IPH:996
# Sn2O3-qd:88989
# Propylene glycol:1030
# B3:5476868
# EA:6341
# Ni:935
# rGO:166001319
# ZIF-8:15245636
# FDT:5288206
# Q219:19309
# TFB:118810322
# X36:66553046
# TT1:18288125
# NaCl:5234
# PANI:136859416
# Au-np:23985
# APPA:12901
# SubPc:11826144
# DFH:69031
# 18-crown-6 ether:28557
# N2,N2,N7,N7-tetrakis(4-methoxyphenyl)spiro[fluorene-9,9'-xanthene]-2,7-diamine:132486515
# PF8-TAA:125325782
# Hexamethylenetetramine:4101
# S7:140835
# T101:16197323
# DIB:7993
# Si-nw:5461123
# PDPP3T:16331842
# AZO:136496666
# DR3TBDTT:154728067
# MATS:22678982
# PFO:51353555
# B63:135454060
# EH44:168434833
# C8-BTBT:59181286
# S101:15998641
# HPB-OMeDPA:15766197
# TAPC:94071
# 4-acetylpyridine:14282
# MoS2:14823
# Cr2O3:517277
# Y3:64955
# CT1:10062713
# Nafion:61889
# B4PyMPM:67967165
# PCT:73188
# D102:57937215
# Vox:169489554
# NaPTH:10422621
# Py:1049
# PBT:87534279
# ZnO-np:14806
# PDVT-10:162678849
# Tea Catachinrich biomolecules:9064
# NiO-c:14805
# Choline chloride:6209
# BenMeIM-Cl:10560335
# H101:102130343
# V1021:7009752
# PDI2:424947
# PEH-2:122388645
# Q221:529894
# PT:23939
# HA1:135460987
# TZ1:2727559
# IT-4f:135395313
# F23:17085
# M103:2734477
# ZnO-mp:14806
# iPrO-DATPA:139204205
# 10-butyl-3,7-diphenylphenoxazine:132570043
# TiN:5352426
# TZ-2:86660533
# Bphen:72812
# Graphene:5462310
# PDBT-co-TT:156594367
# CuInSe2-QDs:56841035
# X59:169503067
# TiO2-hollow spheres:26042
# HTM:2123
# DMC:6624
# SDBS:23662403
# CIL:446363
# P:5462309
# ITIC-Th:131801574
# IPB:9810247
# Diketopyrrolopyrrole:23363597
# TiO2-nanocones:26042
# CsI:70918
# M116:15120
# V1209:51064150
# ZrO2-mp:62395
# CZ-TA:66867222
# Ppy:997
# M107:2761472
# PBDB-T-SF:169550405
# PABA:978
# TMAH:60966
# NP2:3581192
# X1:122705799
# Ppz:1522
# X21:66547425
# WOx:170513399
# 3-PA-SAM:69468
# S-acetylthiocholine chloride:547124
# 3-Butylthiophene:566339
# Py-COF:162678982
# LPP:152192
# PTCDI:66475
# PEDOT:PSS:127255860
# Zn2SnO4:82851
# X14:57519659
# Pentafluorobenzenethiol:13042
# Unknown:962
# SrCl2:61520
# SrSnO3:71374846
# N2200:10481797
# WS2:82938
# TiO2-nanofibers:26042
# Ca(acac)2:71311381
# CGS:446504
# TT0:167311798
# 3-Dodecylthiophene:2733655
# LiQ:23686653
# SWCNTs:5462310
# SO8:121238094
# JY5:145925582
# P3:143245
# TDAB:3014876
# NH4I:25487
# SbI3:24630
# ZnPc:114933
# Z9:134815907
# TPPI:7540
# TZ2:112499928
# KI:4875
# M3:15925951
# TPB:74060
# 3-hydroxypyridine:7971
# FEH:2724621
# TiO2:26042
# PPP:72435
# TT:9283
# CdS-QDs:14783
# MEH-PPV-20:57015767
# BMIMBF4:2734178
# PAA:15277
# MAI:5288727
# SY3:2449589
# H2:783
# HBZ-71:16161850
# BCB:17689
# 4-methoxythiophenol:12765
# MoO2-np:29320
# Zn:SnO2:29011
# B74:586424
# HMDI:13192
# TTC:9283
# Dimethylbiguanide:4091
# Au@TiO2-np:23985
# SY1:23647311
# pTPD:57469793
# m-MTDATA:11061735
# Graphene oxide:5462310
# B2:3953303
# N749:13060451
# TPI:6323266
# PEH-1:122388644
# DTPP:6367229
# A102:69480
# CsAc:8095
# Poly(9-vinylcarbazole):15143
# APTES-SAM:83756
# PVA:11199
# LiI:446753
# CBP:11248716
# B2Pin2:2733548
# OCA:447715
# Ethyl acetate:8857
# YT2:168654836
# PMA:27924
# Rubrene:68203
# PN6:5845
# PbS:14819
# TPDI:2333
# Sinapoyl malate:14605050
# P2:5460700
# PTCBI:10530413
# DM1:11343137
# Al2O3-np:9989226
# X19:57519660
# MWCNTs:297
# 3-Ethylthiophene:74530
# OTS:448337
# 1-ethyl-3-methylimidazolium iodide:11075478
# CsBr:24592
# CAS:6445772
# Thiourea:2723790
# Cs2CO3:10796
# T1:135459782
# XMP:73323
# TPA:27924
# YN1:5466139
# Poly(N-vinylcarbazole):15143
# CT4:86287519
# CrO3:14915
# SnO2-mp:29011
# C70:16131935
# FPI:17429
# 2-PA-SAM:94849
# 4,4'-((2-Hexyl-2H-benzo[d][1,2,3]triazole-4,7-diyl)bis(thiophene5,2-diyl))bis(N,N-bis(4-methoxyphenyl)aniline):16161850
# XOP:53361956
# OTES:APTES-SAM:76485
# F8BT:59704068
# Alq3:16683111
# NPD:18609
# AZO-np:166598
# PBDB-T:164608287
# V1207:7408233
# D101:70068
# M113:69278
# Ca:5460341
# PEABr:70441016
# SiO2:24261
# CuS:165914
# D1:165618797
# 4,4'-(5,10,11-Trihexyl-10,11-dihydro-5H-thieno[2′,3':4,5]pyrrolo [3,2-g]thieno[3,2-b][1,2,3]triazolo[4,5-e]indole-2,8-diyl)bis(N,N-bis(4- methoxyphenyl)aniline):16161850
# In2O3-c:150905
# CuO2:164826
# BCP:65149
# P5:25254399
# MTA:439176
# YC-1:5712
# SnO2-c:29011
# PCBM-70:71777692
# PbF2:24549
# Thiophene:8030
# 2PACz:154704302
# CW4:131953504
# PDINO:101914063
# Polyethylimine:44145008
# Au@CuZnSnSe-np:23985
# BTTP:89891156
# AZ1:2266
# SrTiO3-np:82899
# WO3-np:14811
# SiO2-c:24261
# ZTO:26089
# H3PW12O4:452313
# nPrO-DATPA:139204203
# 4-chlorothiophenol:7815
# ATO:6571
# 4-bromobenzenediazonium tetrafluoroborate:2734810
# BAI:1281
# SnS:426379
# 3-(1-pyridinio)-1-propanesulfonate:84929
# Poly(ethylene oxide):8200
# ETM:36603
# 4,8-bis-(5-bromothiophene-2-yl)-benzo thiadiazole:7222
# X55:44201390
# C9:166450475
# ZnO-nw:14806
# Phen-NaDPO:101876674
# V1036:17750295
# Pyrene:31423
# B1:5352030
# PbS-QDs:14819
# Pyridine:1049
# TBAI:67553
# P6:164946765
# In2S3:16685236
# Poly(2-ethyl-2-oxazoline):66412
# PCBC:3033729
# NiCoO:16217666
# sGO:25577337
# PbTiO3:16211560
# PPy:997
# Ti(OiPr)4:11026
# SP-01:4914
# Q222:54686201
# SnO2-nt:29011
# M111:2733675
# CW5:135398130
# TFM:6931
# AQ:6724
# X18:169449370
# CdS-nw:14783
# EVA:175988
# PTO:449293
# Z1:5565
# M101:2734492
# MCA:1674
# SO9:164664491
# Theophylline:2153
# TiO2-nanosphere:26042
# 2,2’-BiPy:1474
# MoO3:14802
# PEG:174
# Z34:445636
# CoO:14786
# Phenyltrichlorosilane:7372
# Z25:135566693
# X22:25011737
# NP1:5276854
# Au:23985
# V1012:11163977
# SnO2-nw:29011
# TPD:103315
# PS:6423
# CJ-01:70680263
# CD:23973
# BPAPF:21131239
# S5:139341
# Graphene aerogel:5462310
# D149:66577060
# 3-acetylpyridine:9589
# BTT-4:129214826
# Azomethine:135534491
# Titanylphthalocyanine:9808268
# N719 dye:51346531
# DAI:656983
# PCBA:27641
# Carbon-np:297
# X50:170995106
# DBP:3026
# mGO:14792
# Sn2O3-ns:88989
# AuCl3:26030
# Urea:1176
# X26:134812658
# CuO:14829
# 4,4'-(5,10,11-Trihexyl-10,11-dihydro-5H-thieno[2′,3':4,5]pyrrolo [3,2-g]thieno[3,2-b][1,2,3]triazolo[4,5-e]indole-2,8-diyl)bis(N,N-bis(4- (hexyloxy)phenyl)aniline):16161850
# BBA:1499
# NiO-mp:14805
# IT-4F:135395313
# ICL:24640
# PTPD:57469793
# NaOH:14798
# Triazine:123047
# ZnO-c:14806
# DEA:8113
# PTB7-TH:168009990
# PCz:9600419
# N-[3-(Trimethoxysilyl)propyl]ethylenediamine-SAM:15659
# MEH-PPV:57015767
# JY7:73387743
# Benzoic acid:243
# PDA:12599
# CdSe-QDs:14784
# Ethylene glycol:174
# HfO2:292779
# Th101:3469859
# ME2:13847
# EDTA:6049
# BaSnO3-np:13981640
# P4:123286
# F16CuPc:6524626
# BPTI:16130295
# EDT:6049
# CuH:70837
# DCZ-OMeTPA:154733271
# 1bb:135566786
# CT3:146279626
# Ag-nw:23954
# G1:5322399
# M1:119359
# SnO:1237169
# JK-217D:132523264
# 2F:118730119
# C60-N:139034479
# CeO2-c:73963
# 1,2-ethanedithiol:10902
# B2T:12571204
# PFN:41097863
# DPPS:9547090
# Oleic-acid:445639
# ME3:11986115
# Trimethylamine oxide:1145
# Oleylamine:5356789
# ZnPy:3837558
# TiO2-nt:26042
# ZnS:54104351
# AZ2:134163708
# PTAA:19734974
# PCE-10:168009990
# NDT:445060
# Carbozole @ S14:16217868
# PPDI:61009
# V1013:24820702
# NiO-np:14805
# P3HT-MoS2:22950249
# FH-3:102304836
# La2O3:3280778
# 2H-MoS2:14823
# Spiro-TTB:16161851
# YT1:11152920
# s-PANI:PSS:169893
# HATNA-F6:22960239
# GaN:5496571
# C60:123591
# P1:49852424
# Carbon-QDs:297
# Acetyl acetate:7918
# Perylene:9142
# PTCA:443032
# EMIM-PF6:2758873
# V1225:47754
# Red Phosphorous-QDs:123286
# F33:135566662
# Propionic acid:1032
# Montmorillonite:71586775
# MABr:16689569
# bis-PCBM:91972111
# CdI2:277692
# GAN:5496571
# DTS:122842
# XDB:5315356
# P-R:151004
# Glycerol:753
# GD:23982
# [BMIM]BF4:2734178
# SM-1:57339223
# HAT-CN:11069026
# Na2SO4:24436
# M104:2734499
# H7:3542
# Cysteine:5862
# LiTFSI:3816071
# SnO2:29011
# MoOx:139765
# Propylene carbonate:7924
# MEH:297
# Z3:2735045
# TDAC:8098
# 1-OMe-SAM:201262
# PANI:PSS:169893
# MPA:6279
# Z1012:3699961
# PFI:54688400
# SnO2-np:29011
# SO7:95934274
# CsCl:24293
# YT4:11391550
# Spiro-TAD:16134428
# MeO-2PACZ:154704514
# SrTiO3:TiO2-mp:82899
# BaSnO3-mp:13981640
# CMB:4627205
# FeO:444379
# SiO2-mp:24261
# Al2O3-mp:9989226
# TmPyPB:51358305
# V2O5:14814
# D35:445664
# TPL:107985
# HPDI:29924549
# NPB:135363221
# TMTA:27423
# Q205:3526612
# PDMS:24705
# DS1:979735
# Z30:57519677
# BACl:2724127
# M112:643448
# FDA:12762
# Fe2O3:518696
# pFN-Br:168009989
# Rhodamine 101:14844402
# P3HT:566849
# NDI:3033874
# YN3:171392445
# CuI:24350
# Black phosphorous nanosheets:5462309
# PTh:5289223
# PCBB:92043471
# 2-MP:3015569
# CPTA:26170
# Q216:2733979
# PSS:5289217
# P3OT:566852
# Caffeine:2519
# H11:135566420
# YT3:23993
# Polythiophene:8030
# PEO:784
# TPPO:13097
# PbPc:636278
# PFN-Br:168009989
# M114:123098
# NaYF4:Yb:Er-np:25242326
# Z8:10473133
# BTPA:10334852
# PAS:4649
# Zr(acac)4:5463922
# CeOx:73963
# Carbon-nt:297
# X54:155487820
# V1091:11039242
# 4PA-SAM:5922
# HL-2:168296954
# Adamantane:9238
# PDCBT:146012639
# Zn(acac)2:56846320
# Theobromine:5429
# H66:146048132
# X62:57519662
# Pentacene:8671
# H2Pc:86280045
# JW6:167311785
# NO-Graphene-QDs:13387
# PMMA:6658
# 1d @ triphenylamine modified azobenzene dyes:11775
# NiS:120273
# F4-TCNQ:2733307
# PN:1054
# Ethanol amine:700
# ZnO:14806
# TBP:31357
# V1004:144364
# V886:122381839
# 3-Methylthiophene:12024
# Methoxypropionitrile:141829
# CMP:6131
# TIPS-pentacene:15530606
# Methoxyacetonitrile:74442
# Selenium:6326970
# Acetonitrile:6342
# J1:9935639
# Grafted rGO:5462310
# Ta:WOx:162372
# H111:76284
# SnO2-nanosheets:29011
# (3-Aminopropyl)trimethoxysilane:83756
# F4TCNQ:2733307
# AAO:4369393
# M108:7023103
# TFAP:24752865
# PolyTPD:15702182
# H65:119057274
# TiO2-mp:26042
# MK2:44543658
# ZnCdS:44181
# SAED:132249
# SnO2-QDs:29011
# TET:444127
# Zeocoat:62395
# ITO:16217324
# PTEG-1:8172
# PTB7-Th:168009990
# NTPA:150285
# FU7:51049658
# p-amino-benzoic acid:978
# UiO-66:162533375
# BuO-DATPA:139204204
# 1ab:451991
# TaTM:11113597
# M105:731767
# DEH:92377
# TPE-4DPA:77846
# PFB:9923
# ZnO-nanospheres:14806
# COi8DFIC:168010028
# C3-SAM:7848
# V1061:44593742
# Al203-c:9989226
# MnS:672296
# TQ2:44199170
# M117:61365
# CMO:3826051
# V1050:7010016
# graphite nanofibers:5462310
# F6-TCNNQ:59575033
# TQ1:56835755
# ATTA:5460751
# JW7:60172362
# BT:7222
# Ir(MDQ)2(acac):164188896
# V1221:7019133
# Caproic acid:8892
# C101:71587904
# X23:25011738
# KOH:14797
# T103:16197325
# Fluorosilane:6327143
# 4-methoxybenzoic acid:7478
# Carbon:5462310
# PTQ10:139035630
# NaI:66563654
# Y1:23993
# 3TPYMB:53426694
# DM2:31703
# TiO2-nw:26042
# ICBA:129319343
# KCl:4873
# Pbs-QDs:14819
# PbSe:130767
# H-Bi:7095
# Poly-N-vinylcarbazole:15143
# XY1:78871801
# PDI:151809
# Ti:23963
# V1160:7010037
# VO:24411
# C102:66154
# HL-1:253827
# YD2-o-C8:136693780
# Q10:5281915
# PNP:980
# Al2O3-c:9989226
# Porphyrin:66868
# Zn2SnO4-mp:82851
# H18:1266032
# Ps:6423
# MeO-TPD:23069933
# Diethanolamine:8113
# Nb2O5-c:123105
# EtO-DATPA:139204202
# NH4Cl:25517
# Q197:71306957
# Z1013:3856039
# DTB:445027
# ZnP:44543638
# YR3:24936209
# TEABr:6285
# B58:5355150
# M115:355831
# TiO2-nanobeads:26042
# I2:807
# Carbo-QDs:297
# Lif:224478
# WO3:14811
# L-f:6992310
# Al2O3:9989226
# S2:5460602
# NiPc:518870
# Ga2O3:5139834
# Z26:156596363
# DMZ:447297
# H16:448727
# GeO2:14796
# MEAI:12147687
# Sb2O3-np:27652
# CrOx:165971
# PTB7-th:168009990
# CuInSe2-QDss:56841035
# HA2:23644581
# 5,6,11,12-Tetraphenylnaphthacene:68203
# 3C:139166958
# M118:772
# M4:16682741
# RCP:449097
# 1,2-diaminoethane:3301
# TPC:6529
# CuOx:14829
# Polyethylene glycol:174
# tBP:31357
# NiCl2:24385
# X2:134816058
# Benzylamine:7504
# T102:16197276
# ZnSe:4298215
# Carbozole @ S12:16217868
# CdSe:9837007
# Ag-np:23954
# PO-T2T:101887700
# ZnO-nanofibers:14806
# M110:137108687
# Nb2O5:123105
# 3-Hexylthiophene:566849
# OEABS:132578620
# CuInS2:71353413
# Z7:134816218
# TTA:5601
# TPBi:21932919
# OAI:444763
# n-octylammonium iodide:22461615
# In2O3:5150906
# H112:228506
# MDMO-PPV:3559
# Bi2Te3:6379155
# DM:11362
# Z2:134816388
# TcTa:9962045
# TiO2-np:26042
# 2-OMe-SAM:7000
# M2:115209
# ITIC:126843541
# PQT-12:389751
# Rubene:7080
# SY4:43550982
# EGME:8019
# LiSPS:86277430
# D103:24761372
# Phenethylamine:1001
# A101:2997
# M7-TFSI:3816071
# CaTiO3-c:16212381
# TPBS:25458
# HTAB:5974
# J2:135384973
# VOx:169489554
# Imidazolium iodide:66591148
# TZ-3:5482
# PMT:5917
# PVK:15143
# c-TCTA:9962045
# PPN:25200508
# SM13:6217392
# PPV:1023
# DS2:979718
# SeS2:24011
# H64:6914564
# PEI:9033
# M106:17206
# Ag:23954
# CuIn1.5Se3-QDs:13644146
# FeS2:123110
# CuPc:475701
# BPB-M:53384373
# PTCDA:67191
# C60-SAM:102211076
# pentaerythritol tetrakis(3-mercaptopropionate):82056
# n-Butylamine:8007
# Me-4PACz:164186534
# Aniline:6115
# TPTPA:59601002
# YK2:163183327
# CTAB:5974
# TAE:201761
# PDQT:102229705
# CzP:5288014
# Spiro-MeOTAD:16161850
# M6:93893
# Teflon:8301
# 2-acetylpyridine:14286
# ZnNc:57817317
# M102:12082259
# JW8:123132919
# Z1011:3262262
# X51:140728956
# DPO:7105
# MeO-2PACz:154704514
# VNPB:59431022
# 2H-TaS2:82945
# DMF:6228
# G2:13964541
# ZnSO:24424
# MoS2-nanosheets:14823
# Graphitic carbon nitride:768
# H-FL:6853
# LiBr:82050
# PbI2:24931
# Zn2SnO4-c:82851
# Z10:53301832
# SP-12:4311839
# PTA:128001
# Bi2S3:16682960
# Aminocaproic acid:564
# TEAI:6225
# Tetracene:7080
# C12H10B2O4:3488065
# MgO:14792
# Choline Chloride:6209

# %% [markdown]
# ## Extra: How often were identified materials used?
# This question is less relevant and just for the interested.
# How often does an identified material appear in the data?

# %%
sum_etl = 0
sum_htl = 0

for index, material in enumerate(df_new['Material']):
    if not pd.isna(df_new[df_new['Material'] == material]['CID'].values[0]):
        current_etl_sum = len(df_new[df_new['Material'] == material]['etl'].values[0])
        current_htl_sum = len(df_new[df_new['Material'] == material]['htl'].values[0])
        print(f"Etls with {material}: {current_etl_sum}")
        print(f"Htls with {material}: {current_htl_sum}")
        print(f"{index+1}/2534")
        sum_etl = sum_etl + current_etl_sum
        sum_htl = sum_htl + current_htl_sum
# Out:
# Etls with TiO2-c: 22019
# Htls with TiO2-c: 0
# 1/2534
# Etls with bis-C60: 308
# Htls with bis-C60: 9
# 4/2534
# Etls with C60MC12: 1
# Htls with C60MC12: 0
# 9/2534
# Etls with Polyacrylonitrile: 0
# Htls with Polyacrylonitrile: 1
# 11/2534
# Etls with EPA: 1
# Htls with EPA: 1
# 16/2534
# Etls with MgO-c: 18
# Htls with MgO-c: 0
# 17/2534
# Etls with CT2: 0
# Htls with CT2: 1
# 18/2534
# Etls with X25: 0
# Htls with X25: 6
# 20/2534
# Etls with Boron subphthalocyanine chloride: 4
# Htls with Boron subphthalocyanine chloride: 0
# 23/2534
# Etls with IT-M: 2
# Htls with IT-M: 0
# 27/2534
# Etls with LiF: 766
# Htls with LiF: 14
# 28/2534
# Etls with V1056: 0
# Htls with V1056: 2
# 30/2534
# Etls with PTT: 0
# Htls with PTT: 1
# 34/2534
# Etls with ME1: 0
# Htls with ME1: 1
# 36/2534
# Etls with tert-CuBuPc: 0
# Htls with tert-CuBuPc: 1
# 38/2534
# Etls with ZrO2: 8
# Htls with ZrO2: 0
# 46/2534
# Etls with PVP: 6
# Htls with PVP: 13
# 58/2534
# Etls with TaTm: 0
# Htls with TaTm: 73
# 61/2534
# Etls with V1102: 0
# Htls with V1102: 2
# 62/2534
# Etls with Q198: 0
# Htls with Q198: 1
# 63/2534
# Etls with Cu: 0
# Htls with Cu: 2
# 67/2534
# Etls with Cu2O: 0
# Htls with Cu2O: 56
# 70/2534
# Etls with IDIC: 6
# Htls with IDIC: 0
# 71/2534
# Etls with IEICO-4F: 0
# Htls with IEICO-4F: 9
# 72/2534
# Etls with M109: 0
# Htls with M109: 2
# 75/2534
# Etls with Au-nw: 2
# Htls with Au-nw: 7
# 79/2534
# Etls with BaSnO3-nw: 1
# Htls with BaSnO3-nw: 0
# 83/2534
# Etls with CuP: 0
# Htls with CuP: 4
# 85/2534
# Etls with Polystyrene: 9
# Htls with Polystyrene: 7
# 87/2534
# Etls with Ba(OH)2: 6
# Htls with Ba(OH)2: 0
# 88/2534
# Etls with TOPO: 0
# Htls with TOPO: 2
# 90/2534
# Etls with Co3O4: 0
# Htls with Co3O4: 5
# 92/2534
# Etls with SQ2: 1
# Htls with SQ2: 1
# 94/2534
# Etls with N719: 10
# Htls with N719: 0
# 95/2534
# Etls with DTBT: 0
# Htls with DTBT: 1
# 96/2534
# Etls with JY6: 0
# Htls with JY6: 7
# 102/2534
# Etls with YK1: 0
# Htls with YK1: 2
# 105/2534
# Etls with CuSCN: 0
# Htls with CuSCN: 266
# 106/2534
# Etls with rGO:TiO2-nanofibrse: 3
# Htls with rGO:TiO2-nanofibrse: 0
# 113/2534
# Etls with PCBM-60: 10454
# Htls with PCBM-60: 49
# 114/2534
# Etls with TZ3: 0
# Htls with TZ3: 2
# 121/2534
# Etls with CdS: 113
# Htls with CdS: 0
# 125/2534
# Etls with NiO: 2
# Htls with NiO: 190
# 127/2534
# Etls with DTAB: 5
# Htls with DTAB: 0
# 134/2534
# Etls with SY2: 0
# Htls with SY2: 5
# 135/2534
# Etls with SM: 0
# Htls with SM: 5
# 139/2534
# Etls with IPH: 18
# Htls with IPH: 0
# 144/2534
# Etls with Sn2O3-qd: 0
# Htls with Sn2O3-qd: 2
# 147/2534
# Etls with Propylene glycol: 0
# Htls with Propylene glycol: 0
# 149/2534
# Etls with B3: 0
# Htls with B3: 1
# 155/2534
# Etls with EA: 2
# Htls with EA: 0
# 157/2534
# Etls with Ni: 0
# Htls with Ni: 16
# 165/2534
# Etls with rGO: 6
# Htls with rGO: 42
# 166/2534
# Etls with ZIF-8: 5
# Htls with ZIF-8: 0
# 168/2534
# Etls with FDT: 0
# Htls with FDT: 10
# 169/2534
# Etls with Q219: 0
# Htls with Q219: 2
# 172/2534
# Etls with TFB: 0
# Htls with TFB: 19
# 176/2534
# Etls with X36: 0
# Htls with X36: 1
# 178/2534
# Etls with TT1: 0
# Htls with TT1: 26
# 180/2534
# Etls with NaCl: 0
# Htls with NaCl: 2
# 183/2534
# Etls with PANI: 0
# Htls with PANI: 26
# 185/2534
# Etls with Au-np: 28
# Htls with Au-np: 20
# 191/2534
# Etls with APPA: 0
# Htls with APPA: 1
# 194/2534
# Etls with SubPc: 0
# Htls with SubPc: 1
# 195/2534
# Etls with DFH: 0
# Htls with DFH: 4
# 198/2534
# Etls with 18-crown-6 ether: 0
# Htls with 18-crown-6 ether: 5
# 202/2534
# Etls with N2,N2,N7,N7-tetrakis(4-methoxyphenyl)spiro[fluorene-9,9'-xanthene]-2,7-diamine: 0
# Htls with N2,N2,N7,N7-tetrakis(4-methoxyphenyl)spiro[fluorene-9,9'-xanthene]-2,7-diamine: 2
# 203/2534
# Etls with PF8-TAA: 0
# Htls with PF8-TAA: 3
# 204/2534
# Etls with Hexamethylenetetramine: 2
# Htls with Hexamethylenetetramine: 0
# 209/2534
# Etls with S7: 0
# Htls with S7: 1
# 210/2534
# Etls with T101: 0
# Htls with T101: 1
# 213/2534
# Etls with DIB: 0
# Htls with DIB: 1
# 214/2534
# Etls with Si-nw: 4
# Htls with Si-nw: 0
# 219/2534
# Etls with PDPP3T: 6
# Htls with PDPP3T: 4
# 222/2534
# Etls with AZO: 55
# Htls with AZO: 0
# 223/2534
# Etls with DR3TBDTT: 0
# Htls with DR3TBDTT: 11
# 226/2534
# Etls with MATS: 10
# Htls with MATS: 0
# 228/2534
# Etls with PFO: 0
# Htls with PFO: 3
# 240/2534
# Etls with B63: 0
# Htls with B63: 1
# 241/2534
# Etls with EH44: 0
# Htls with EH44: 26
# 242/2534
# Etls with C8-BTBT: 0
# Htls with C8-BTBT: 3
# 249/2534
# Etls with S101: 0
# Htls with S101: 2
# 250/2534
# Etls with HPB-OMeDPA: 0
# Htls with HPB-OMeDPA: 2
# 251/2534
# Etls with TAPC: 0
# Htls with TAPC: 55
# 253/2534
# Etls with 4-acetylpyridine: 4
# Htls with 4-acetylpyridine: 0
# 254/2534
# Etls with MoS2: 7
# Htls with MoS2: 45
# 255/2534
# Etls with Cr2O3: 6
# Htls with Cr2O3: 0
# 261/2534
# Etls with Y3: 0
# Htls with Y3: 2
# 263/2534
# Etls with CT1: 0
# Htls with CT1: 2
# 265/2534
# Etls with Nafion: 0
# Htls with Nafion: 3
# 268/2534
# Etls with B4PyMPM: 6
# Htls with B4PyMPM: 0
# 270/2534
# Etls with PCT: 0
# Htls with PCT: 3
# 271/2534
# Etls with D102: 0
# Htls with D102: 1
# 275/2534
# Etls with Vox: 0
# Htls with Vox: 2
# 282/2534
# Etls with NaPTH: 1
# Htls with NaPTH: 0
# 285/2534
# Etls with Py: 0
# Htls with Py: 1
# 288/2534
# Etls with PBT: 0
# Htls with PBT: 3
# 289/2534
# Etls with ZnO-np: 843
# Htls with ZnO-np: 0
# 293/2534
# Etls with PDVT-10: 0
# Htls with PDVT-10: 1
# 296/2534
# Etls with Tea Catachinrich biomolecules: 0
# Htls with Tea Catachinrich biomolecules: 1
# 298/2534
# Etls with NiO-c: 23
# Htls with NiO-c: 1966
# 306/2534
# Etls with Choline chloride: 14
# Htls with Choline chloride: 5
# 307/2534
# Etls with BenMeIM-Cl: 8
# Htls with BenMeIM-Cl: 0
# 309/2534
# Etls with H101: 0
# Htls with H101: 4
# 310/2534
# Etls with V1021: 0
# Htls with V1021: 1
# 319/2534
# Etls with PDI2: 6
# Htls with PDI2: 0
# 320/2534
# Etls with PEH-2: 0
# Htls with PEH-2: 2
# 327/2534
# Etls with Q221: 0
# Htls with Q221: 3
# 331/2534
# Etls with PT: 0
# Htls with PT: 8
# 336/2534
# Etls with HA1: 0
# Htls with HA1: 2
# 338/2534
# Etls with TZ1: 0
# Htls with TZ1: 2
# 342/2534
# Etls with IT-4f: 1
# Htls with IT-4f: 0
# 343/2534
# Etls with F23: 0
# Htls with F23: 1
# 344/2534
# Etls with M103: 0
# Htls with M103: 2
# 345/2534
# Etls with ZnO-mp: 51
# Htls with ZnO-mp: 0
# 347/2534
# Etls with iPrO-DATPA: 0
# Htls with iPrO-DATPA: 1
# 349/2534
# Etls with 10-butyl-3,7-diphenylphenoxazine: 0
# Htls with 10-butyl-3,7-diphenylphenoxazine: 1
# 350/2534
# Etls with TiN: 3
# Htls with TiN: 0
# 353/2534
# Etls with TZ-2: 0
# Htls with TZ-2: 0
# 357/2534
# Etls with Bphen: 523
# Htls with Bphen: 0
# 360/2534
# Etls with Graphene: 40
# Htls with Graphene: 23
# 361/2534
# Etls with PDBT-co-TT: 0
# Htls with PDBT-co-TT: 4
# 362/2534
# Etls with CuInSe2-QDs: 0
# Htls with CuInSe2-QDs: 5
# 363/2534
# Etls with X59: 0
# Htls with X59: 5
# 365/2534
# Etls with TiO2-hollow spheres: 1
# Htls with TiO2-hollow spheres: 0
# 367/2534
# Etls with HTM: 0
# Htls with HTM: 28
# 368/2534
# Etls with DMC: 0
# Htls with DMC: 0
# 369/2534
# Etls with SDBS: 0
# Htls with SDBS: 4
# 378/2534
# Etls with CIL: 5
# Htls with CIL: 0
# 379/2534
# Etls with P: 0
# Htls with P: 1
# 382/2534
# Etls with ITIC-Th: 6
# Htls with ITIC-Th: 0
# 383/2534
# Etls with IPB: 2
# Htls with IPB: 0
# 386/2534
# Etls with Diketopyrrolopyrrole: 0
# Htls with Diketopyrrolopyrrole: 2
# 390/2534
# Etls with TiO2-nanocones: 12
# Htls with TiO2-nanocones: 0
# 395/2534
# Etls with CsI: 1
# Htls with CsI: 0
# 398/2534
# Etls with M116: 0
# Htls with M116: 1
# 401/2534
# Etls with V1209: 0
# Htls with V1209: 1
# 405/2534
# Etls with ZrO2-mp: 791
# Htls with ZrO2-mp: 0
# 408/2534
# Etls with CZ-TA: 0
# Htls with CZ-TA: 3
# 409/2534
# Etls with Ppy: 0
# Htls with Ppy: 2
# 410/2534
# Etls with M107: 0
# Htls with M107: 2
# 412/2534
# Etls with PBDB-T-SF: 0
# Htls with PBDB-T-SF: 0
# 427/2534
# Etls with PABA: 0
# Htls with PABA: 1
# 430/2534
# Etls with TMAH: 4
# Htls with TMAH: 0
# 431/2534
# Etls with NP2: 0
# Htls with NP2: 1
# 435/2534
# Etls with X1: 0
# Htls with X1: 7
# 438/2534
# Etls with Ppz: 1
# Htls with Ppz: 0
# 441/2534
# Etls with X21: 0
# Htls with X21: 1
# 446/2534
# Etls with WOx: 29
# Htls with WOx: 10
# 451/2534
# Etls with 3-PA-SAM: 1
# Htls with 3-PA-SAM: 0
# 456/2534
# Etls with S-acetylthiocholine chloride: 3
# Htls with S-acetylthiocholine chloride: 0
# 460/2534
# Etls with 3-Butylthiophene: 0
# Htls with 3-Butylthiophene: 4
# 461/2534
# Etls with Py-COF: 0
# Htls with Py-COF: 1
# 462/2534
# Etls with LPP: 1
# Htls with LPP: 0
# 467/2534
# Etls with PTCDI: 1
# Htls with PTCDI: 0
# 469/2534
# Etls with PEDOT:PSS: 20
# Htls with PEDOT:PSS: 7281
# 470/2534
# Etls with Zn2SnO4: 14
# Htls with Zn2SnO4: 0
# 481/2534
# Etls with X14: 0
# Htls with X14: 1
# 482/2534
# Etls with Pentafluorobenzenethiol: 0
# Htls with Pentafluorobenzenethiol: 2
# 484/2534
# Etls with Unknown: 95
# Htls with Unknown: 84
# 487/2534
# Etls with SrCl2: 0
# Htls with SrCl2: 5
# 489/2534
# Etls with SrSnO3: 2
# Htls with SrSnO3: 0
# 496/2534
# Etls with N2200: 28
# Htls with N2200: 0
# 497/2534
# Etls with WS2: 0
# Htls with WS2: 3
# 499/2534
# Etls with TiO2-nanofibers: 35
# Htls with TiO2-nanofibers: 0
# 503/2534
# Etls with Ca(acac)2: 8
# Htls with Ca(acac)2: 0
# 506/2534
# Etls with CGS: 0
# Htls with CGS: 2
# 508/2534
# Etls with TT0: 0
# Htls with TT0: 7
# 517/2534
# Etls with 3-Dodecylthiophene: 0
# Htls with 3-Dodecylthiophene: 4
# 522/2534
# Etls with LiQ: 3
# Htls with LiQ: 0
# 523/2534
# Etls with SWCNTs: 10
# Htls with SWCNTs: 49
# 526/2534
# Etls with SO8: 0
# Htls with SO8: 1
# 528/2534
# Etls with JY5: 0
# Htls with JY5: 6
# 533/2534
# Etls with P3: 1
# Htls with P3: 12
# 534/2534
# Etls with TDAB: 0
# Htls with TDAB: 1
# 536/2534
# Etls with NH4I: 5
# Htls with NH4I: 0
# 540/2534
# Etls with SbI3: 2
# Htls with SbI3: 0
# 544/2534
# Etls with ZnPc: 0
# Htls with ZnPc: 14
# 546/2534
# Etls with Z9: 0
# Htls with Z9: 1
# 547/2534
# Etls with TPPI: 2
# Htls with TPPI: 0
# 548/2534
# Etls with TZ2: 0
# Htls with TZ2: 2
# 549/2534
# Etls with KI: 0
# Htls with KI: 0
# 551/2534
# Etls with M3: 0
# Htls with M3: 3
# 553/2534
# Etls with TPB: 0
# Htls with TPB: 1
# 554/2534
# Etls with 3-hydroxypyridine: 0
# Htls with 3-hydroxypyridine: 1
# 555/2534
# Etls with FEH: 0
# Htls with FEH: 1
# 557/2534
# Etls with TiO2: 116
# Htls with TiO2: 0
# 560/2534
# Etls with PPP: 0
# Htls with PPP: 2
# 561/2534
# Etls with TT: 0
# Htls with TT: 0
# 563/2534
# Etls with CdS-QDs: 2
# Htls with CdS-QDs: 0
# 573/2534
# Etls with MEH-PPV-20: 0
# Htls with MEH-PPV-20: 1
# 576/2534
# Etls with BMIMBF4: 3
# Htls with BMIMBF4: 3
# 582/2534
# Etls with PAA: 2
# Htls with PAA: 0
# 585/2534
# Etls with MAI: 7
# Htls with MAI: 0
# 588/2534
# Etls with SY3: 0
# Htls with SY3: 5
# 589/2534
# Etls with H2: 0
# Htls with H2: 3
# 592/2534
# Etls with HBZ-71: 0
# Htls with HBZ-71: 1
# 597/2534
# Etls with BCB: 4
# Htls with BCB: 0
# 599/2534
# Etls with 4-methoxythiophenol: 2
# Htls with 4-methoxythiophenol: 0
# 601/2534
# Etls with MoO2-np: 0
# Htls with MoO2-np: 3
# 606/2534
# Etls with Zn:SnO2: 1
# Htls with Zn:SnO2: 0
# 610/2534
# Etls with B74: 0
# Htls with B74: 3
# 619/2534
# Etls with HMDI: 0
# Htls with HMDI: 1
# 620/2534
# Etls with TTC: 4
# Htls with TTC: 0
# 623/2534
# Etls with Dimethylbiguanide: 4
# Htls with Dimethylbiguanide: 0
# 629/2534
# Etls with Au@TiO2-np: 10
# Htls with Au@TiO2-np: 0
# 633/2534
# Etls with SY1: 0
# Htls with SY1: 5
# 634/2534
# Etls with pTPD: 0
# Htls with pTPD: 10
# 635/2534
# Etls with m-MTDATA: 0
# Htls with m-MTDATA: 22
# 637/2534
# Etls with Graphene oxide: 6
# Htls with Graphene oxide: 118
# 641/2534
# Etls with B2: 0
# Htls with B2: 1
# 642/2534
# Etls with N749: 0
# Htls with N749: 5
# 643/2534
# Etls with TPI: 0
# Htls with TPI: 1
# 644/2534
# Etls with PEH-1: 0
# Htls with PEH-1: 2
# 651/2534
# Etls with DTPP: 2
# Htls with DTPP: 0
# 656/2534
# Etls with A102: 0
# Htls with A102: 14
# 663/2534
# Etls with CsAc: 2
# Htls with CsAc: 0
# 665/2534
# Etls with Poly(9-vinylcarbazole): 1
# Htls with Poly(9-vinylcarbazole): 0
# 668/2534
# Etls with APTES-SAM: 8
# Htls with APTES-SAM: 0
# 674/2534
# Etls with PVA: 0
# Htls with PVA: 0
# 675/2534
# Etls with LiI: 0
# Htls with LiI: 1
# 677/2534
# Etls with CBP: 0
# Htls with CBP: 10
# 680/2534
# Etls with B2Pin2: 1
# Htls with B2Pin2: 0
# 683/2534
# Etls with OCA: 1
# Htls with OCA: 0
# 684/2534
# Etls with Ethyl acetate: 7
# Htls with Ethyl acetate: 22
# 687/2534
# Etls with YT2: 0
# Htls with YT2: 1
# 691/2534
# Etls with PMA: 0
# Htls with PMA: 2
# 693/2534
# Etls with Rubrene: 0
# Htls with Rubrene: 4
# 694/2534
# Etls with PN6: 4
# Htls with PN6: 0
# 695/2534
# Etls with PbS: 5
# Htls with PbS: 8
# 696/2534
# Etls with TPDI: 0
# Htls with TPDI: 2
# 699/2534
# Etls with Sinapoyl malate: 10
# Htls with Sinapoyl malate: 0
# 703/2534
# Etls with P2: 1
# Htls with P2: 13
# 706/2534
# Etls with PTCBI: 6
# Htls with PTCBI: 0
# 710/2534
# Etls with DM1: 0
# Htls with DM1: 1
# 713/2534
# Etls with Al2O3-np: 10
# Htls with Al2O3-np: 15
# 714/2534
# Etls with X19: 0
# Htls with X19: 1
# 715/2534
# Etls with MWCNTs: 0
# Htls with MWCNTs: 13
# 716/2534
# Etls with 3-Ethylthiophene: 0
# Htls with 3-Ethylthiophene: 4
# 726/2534
# Etls with OTS: 4
# Htls with OTS: 0
# 734/2534
# Etls with 1-ethyl-3-methylimidazolium iodide: 17
# Htls with 1-ethyl-3-methylimidazolium iodide: 0
# 736/2534
# Etls with CsBr: 8
# Htls with CsBr: 0
# 742/2534
# Etls with CAS: 0
# Htls with CAS: 1
# 744/2534
# Etls with Thiourea: 3
# Htls with Thiourea: 0
# 746/2534
# Etls with Cs2CO3: 26
# Htls with Cs2CO3: 0
# 747/2534
# Etls with T1: 0
# Htls with T1: 1
# 748/2534
# Etls with XMP: 0
# Htls with XMP: 2
# 751/2534
# Etls with TPA: 0
# Htls with TPA: 2
# 753/2534
# Etls with YN1: 0
# Htls with YN1: 1
# 755/2534
# Etls with Poly(N-vinylcarbazole): 0
# Htls with Poly(N-vinylcarbazole): 0
# 757/2534
# Etls with CT4: 0
# Htls with CT4: 1
# 760/2534
# Etls with CrO3: 0
# Htls with CrO3: 8
# 769/2534
# Etls with SnO2-mp: 69
# Htls with SnO2-mp: 0
# 772/2534
# Etls with C70: 35
# Htls with C70: 0
# 774/2534
# Etls with FPI: 2
# Htls with FPI: 0
# 777/2534
# Etls with 2-PA-SAM: 1
# Htls with 2-PA-SAM: 0
# 778/2534
# Etls with 4,4'-((2-Hexyl-2H-benzo[d][1,2,3]triazole-4,7-diyl)bis(thiophene5,2-diyl))bis(N,N-bis(4-methoxyphenyl)aniline): 0
# Htls with 4,4'-((2-Hexyl-2H-benzo[d][1,2,3]triazole-4,7-diyl)bis(thiophene5,2-diyl))bis(N,N-bis(4-methoxyphenyl)aniline): 2
# 780/2534
# Etls with XOP: 0
# Htls with XOP: 2
# 784/2534
# Etls with OTES:APTES-SAM: 3
# Htls with OTES:APTES-SAM: 0
# 785/2534
# Etls with F8BT: 7
# Htls with F8BT: 0
# 788/2534
# Etls with Alq3: 15
# Htls with Alq3: 0
# 789/2534
# Etls with NPD: 0
# Htls with NPD: 1
# 793/2534
# Etls with AZO-np: 121
# Htls with AZO-np: 0
# 798/2534
# Etls with PBDB-T: 0
# Htls with PBDB-T: 5
# 801/2534
# Etls with V1207: 0
# Htls with V1207: 1
# 803/2534
# Etls with D101: 0
# Htls with D101: 1
# 810/2534
# Etls with M113: 0
# Htls with M113: 1
# 811/2534
# Etls with Ca: 35
# Htls with Ca: 1
# 812/2534
# Etls with PEABr: 8
# Htls with PEABr: 0
# 813/2534
# Etls with SiO2: 2
# Htls with SiO2: 1
# 814/2534
# Etls with CuS: 0
# Htls with CuS: 13
# 817/2534
# Etls with D1: 0
# Htls with D1: 1
# 818/2534
# Etls with 4,4'-(5,10,11-Trihexyl-10,11-dihydro-5H-thieno[2′,3':4,5]pyrrolo [3,2-g]thieno[3,2-b][1,2,3]triazolo[4,5-e]indole-2,8-diyl)bis(N,N-bis(4- methoxyphenyl)aniline): 0
# Htls with 4,4'-(5,10,11-Trihexyl-10,11-dihydro-5H-thieno[2′,3':4,5]pyrrolo [3,2-g]thieno[3,2-b][1,2,3]triazolo[4,5-e]indole-2,8-diyl)bis(N,N-bis(4- methoxyphenyl)aniline): 2
# 820/2534
# Etls with In2O3-c: 26
# Htls with In2O3-c: 0
# 821/2534
# Etls with CuO2: 0
# Htls with CuO2: 2
# 824/2534
# Etls with BCP: 5613
# Htls with BCP: 13
# 827/2534
# Etls with P5: 0
# Htls with P5: 1
# 838/2534
# Etls with MTA: 0
# Htls with MTA: 1
# 843/2534
# Etls with YC-1: 0
# Htls with YC-1: 4
# 852/2534
# Etls with SnO2-c: 2236
# Htls with SnO2-c: 0
# 853/2534
# Etls with PCBM-70: 277
# Htls with PCBM-70: 0
# 854/2534
# Etls with PbF2: 2
# Htls with PbF2: 0
# 857/2534
# Etls with Thiophene: 0
# Htls with Thiophene: 10
# 861/2534
# Etls with 2PACz: 0
# Htls with 2PACz: 70
# 868/2534
# Etls with CW4: 0
# Htls with CW4: 2
# 878/2534
# Etls with PDINO: 23
# Htls with PDINO: 0
# 880/2534
# Etls with Polyethylimine: 9
# Htls with Polyethylimine: 0
# 882/2534
# Etls with Au@CuZnSnSe-np: 0
# Htls with Au@CuZnSnSe-np: 1
# 884/2534
# Etls with BTTP: 0
# Htls with BTTP: 1
# 890/2534
# Etls with AZ1: 0
# Htls with AZ1: 1
# 894/2534
# Etls with SrTiO3-np: 6
# Htls with SrTiO3-np: 0
# 897/2534
# Etls with WO3-np: 5
# Htls with WO3-np: 0
# 899/2534
# Etls with SiO2-c: 6
# Htls with SiO2-c: 0
# 901/2534
# Etls with ZTO: 20
# Htls with ZTO: 0
# 903/2534
# Etls with H3PW12O4: 1
# Htls with H3PW12O4: 0
# 905/2534
# Etls with nPrO-DATPA: 0
# Htls with nPrO-DATPA: 1
# 907/2534
# Etls with 4-chlorothiophenol: 0
# Htls with 4-chlorothiophenol: 2
# 910/2534
# Etls with ATO: 2
# Htls with ATO: 0
# 915/2534
# Etls with 4-bromobenzenediazonium tetrafluoroborate: 0
# Htls with 4-bromobenzenediazonium tetrafluoroborate: 2
# 917/2534
# Etls with BAI: 1
# Htls with BAI: 2
# 918/2534
# Etls with SnS: 8
# Htls with SnS: 9
# 921/2534
# Etls with 3-(1-pyridinio)-1-propanesulfonate: 6
# Htls with 3-(1-pyridinio)-1-propanesulfonate: 0
# 922/2534
# Etls with Poly(ethylene oxide): 0
# Htls with Poly(ethylene oxide): 3
# 925/2534
# Etls with ETM: 6
# Htls with ETM: 0
# 927/2534
# Etls with 4,8-bis-(5-bromothiophene-2-yl)-benzo thiadiazole: 0
# Htls with 4,8-bis-(5-bromothiophene-2-yl)-benzo thiadiazole: 1
# 934/2534
# Etls with X55: 0
# Htls with X55: 1
# 940/2534
# Etls with C9: 3
# Htls with C9: 0
# 942/2534
# Etls with ZnO-nw: 265
# Htls with ZnO-nw: 4
# 943/2534
# Etls with Phen-NaDPO: 17
# Htls with Phen-NaDPO: 0
# 946/2534
# Etls with V1036: 0
# Htls with V1036: 3
# 954/2534
# Etls with Pyrene: 0
# Htls with Pyrene: 1
# 959/2534
# Etls with B1: 0
# Htls with B1: 1
# 967/2534
# Etls with PbS-QDs: 8
# Htls with PbS-QDs: 20
# 968/2534
# Etls with Pyridine: 0
# Htls with Pyridine: 3
# 972/2534
# Etls with TBAI: 2
# Htls with TBAI: 0
# 973/2534
# Etls with P6: 0
# Htls with P6: 1
# 976/2534
# Etls with In2S3: 21
# Htls with In2S3: 0
# 977/2534
# Etls with Poly(2-ethyl-2-oxazoline): 1
# Htls with Poly(2-ethyl-2-oxazoline): 10
# 978/2534
# Etls with PCBC: 9
# Htls with PCBC: 0
# 987/2534
# Etls with NiCoO: 0
# Htls with NiCoO: 4
# 989/2534
# Etls with sGO: 0
# Htls with sGO: 2
# 990/2534
# Etls with PbTiO3: 10
# Htls with PbTiO3: 0
# 991/2534
# Etls with PPy: 1
# Htls with PPy: 0
# 996/2534
# Etls with Ti(OiPr)4: 1
# Htls with Ti(OiPr)4: 0
# 1006/2534
# Etls with SP-01: 0
# Htls with SP-01: 4
# 1007/2534
# Etls with Q222: 0
# Htls with Q222: 2
# 1009/2534
# Etls with SnO2-nt: 1
# Htls with SnO2-nt: 0
# 1011/2534
# Etls with M111: 0
# Htls with M111: 1
# 1012/2534
# Etls with CW5: 0
# Htls with CW5: 1
# 1014/2534
# Etls with TFM: 0
# Htls with TFM: 1
# 1016/2534
# Etls with AQ: 0
# Htls with AQ: 1
# 1020/2534
# Etls with X18: 0
# Htls with X18: 1
# 1021/2534
# Etls with CdS-nw: 7
# Htls with CdS-nw: 0
# 1027/2534
# Etls with EVA: 4
# Htls with EVA: 3
# 1030/2534
# Etls with PTO: 11
# Htls with PTO: 0
# 1031/2534
# Etls with Z1: 0
# Htls with Z1: 3
# 1033/2534
# Etls with M101: 0
# Htls with M101: 2
# 1035/2534
# Etls with MCA: 1
# Htls with MCA: 0
# 1037/2534
# Etls with SO9: 0
# Htls with SO9: 1
# 1044/2534
# Etls with Theophylline: 0
# Htls with Theophylline: 2
# 1045/2534
# Etls with TiO2-nanosphere: 22
# Htls with TiO2-nanosphere: 0
# 1046/2534
# Etls with 2,2’-BiPy: 0
# Htls with 2,2’-BiPy: 2
# 1048/2534
# Etls with MoO3: 6
# Htls with MoO3: 212
# 1049/2534
# Etls with PEG: 11
# Htls with PEG: 8
# 1052/2534
# Etls with Z34: 0
# Htls with Z34: 2
# 1054/2534
# Etls with CoO: 0
# Htls with CoO: 1
# 1055/2534
# Etls with Phenyltrichlorosilane: 5
# Htls with Phenyltrichlorosilane: 0
# 1056/2534
# Etls with Z25: 0
# Htls with Z25: 2
# 1068/2534
# Etls with X22: 0
# Htls with X22: 2
# 1069/2534
# Etls with NP1: 0
# Htls with NP1: 1
# 1070/2534
# Etls with Au: 14
# Htls with Au: 8
# 1071/2534
# Etls with V1012: 0
# Htls with V1012: 1
# 1072/2534
# Etls with SnO2-nw: 24
# Htls with SnO2-nw: 0
# 1076/2534
# Etls with TPD: 0
# Htls with TPD: 15
# 1079/2534
# Etls with PS: 10
# Htls with PS: 8
# 1081/2534
# Etls with CJ-01: 0
# Htls with CJ-01: 1
# 1082/2534
# Etls with CD: 1
# Htls with CD: 0
# 1083/2534
# Etls with BPAPF: 0
# Htls with BPAPF: 1
# 1084/2534
# Etls with S5: 0
# Htls with S5: 4
# 1091/2534
# Etls with Graphene aerogel: 0
# Htls with Graphene aerogel: 2
# 1093/2534
# Etls with D149: 4
# Htls with D149: 0
# 1094/2534
# Etls with 3-acetylpyridine: 4
# Htls with 3-acetylpyridine: 0
# 1095/2534
# Etls with BTT-4: 0
# Htls with BTT-4: 1
# 1101/2534
# Etls with Azomethine: 0
# Htls with Azomethine: 1
# 1102/2534
# Etls with Titanylphthalocyanine: 0
# Htls with Titanylphthalocyanine: 3
# 1104/2534
# Etls with N719 dye: 0
# Htls with N719 dye: 3
# 1105/2534
# Etls with DAI: 0
# Htls with DAI: 1
# 1107/2534
# Etls with PCBA: 55
# Htls with PCBA: 0
# 1111/2534
# Etls with Carbon-np: 11
# Htls with Carbon-np: 8
# 1114/2534
# Etls with X50: 0
# Htls with X50: 1
# 1119/2534
# Etls with DBP: 7
# Htls with DBP: 0
# 1120/2534
# Etls with mGO: 0
# Htls with mGO: 2
# 1122/2534
# Etls with Sn2O3-ns: 1
# Htls with Sn2O3-ns: 0
# 1129/2534
# Etls with AuCl3: 0
# Htls with AuCl3: 4
# 1133/2534
# Etls with Urea: 2
# Htls with Urea: 0
# 1134/2534
# Etls with X26: 0
# Htls with X26: 1
# 1136/2534
# Etls with CuO: 0
# Htls with CuO: 19
# 1141/2534
# Etls with 4,4'-(5,10,11-Trihexyl-10,11-dihydro-5H-thieno[2′,3':4,5]pyrrolo [3,2-g]thieno[3,2-b][1,2,3]triazolo[4,5-e]indole-2,8-diyl)bis(N,N-bis(4- (hexyloxy)phenyl)aniline): 0
# Htls with 4,4'-(5,10,11-Trihexyl-10,11-dihydro-5H-thieno[2′,3':4,5]pyrrolo [3,2-g]thieno[3,2-b][1,2,3]triazolo[4,5-e]indole-2,8-diyl)bis(N,N-bis(4- (hexyloxy)phenyl)aniline): 2
# 1142/2534
# Etls with BBA: 1
# Htls with BBA: 1
# 1144/2534
# Etls with NiO-mp: 8
# Htls with NiO-mp: 159
# 1148/2534
# Etls with IT-4F: 0
# Htls with IT-4F: 2
# 1158/2534
# Etls with ICL: 1
# Htls with ICL: 0
# 1163/2534
# Etls with PTPD: 0
# Htls with PTPD: 37
# 1164/2534
# Etls with NaOH: 1
# Htls with NaOH: 0
# 1165/2534
# Etls with Triazine: 0
# Htls with Triazine: 2
# 1171/2534
# Etls with ZnO-c: 1071
# Htls with ZnO-c: 0
# 1172/2534
# Etls with DEA: 0
# Htls with DEA: 8
# 1174/2534
# Etls with PTB7-TH: 0
# Htls with PTB7-TH: 2
# 1176/2534
# Etls with PCz: 0
# Htls with PCz: 1
# 1177/2534
# Etls with N-[3-(Trimethoxysilyl)propyl]ethylenediamine-SAM: 2
# Htls with N-[3-(Trimethoxysilyl)propyl]ethylenediamine-SAM: 0
# 1180/2534
# Etls with MEH-PPV: 0
# Htls with MEH-PPV: 15
# 1184/2534
# Etls with JY7: 0
# Htls with JY7: 7
# 1186/2534
# Etls with Benzoic acid: 2
# Htls with Benzoic acid: 0
# 1189/2534
# Etls with PDA: 2
# Htls with PDA: 0
# 1190/2534
# Etls with CdSe-QDs: 18
# Htls with CdSe-QDs: 4
# 1193/2534
# Etls with Ethylene glycol: 0
# Htls with Ethylene glycol: 2
# 1204/2534
# Etls with HfO2: 7
# Htls with HfO2: 5
# 1212/2534
# Etls with Th101: 0
# Htls with Th101: 1
# 1216/2534
# Etls with ME2: 0
# Htls with ME2: 1
# 1219/2534
# Etls with EDTA: 2
# Htls with EDTA: 0
# 1222/2534
# Etls with BaSnO3-np: 7
# Htls with BaSnO3-np: 0
# 1225/2534
# Etls with P4: 1
# Htls with P4: 1
# 1235/2534
# Etls with F16CuPc: 1
# Htls with F16CuPc: 1
# 1239/2534
# Etls with BPTI: 4
# Htls with BPTI: 0
# 1250/2534
# Etls with EDT: 0
# Htls with EDT: 3
# 1253/2534
# Etls with CuH: 0
# Htls with CuH: 1
# 1255/2534
# Etls with DCZ-OMeTPA: 0
# Htls with DCZ-OMeTPA: 4
# 1258/2534
# Etls with 1bb: 0
# Htls with 1bb: 3
# 1262/2534
# Etls with CT3: 0
# Htls with CT3: 1
# 1268/2534
# Etls with Ag-nw: 2
# Htls with Ag-nw: 6
# 1274/2534
# Etls with G1: 0
# Htls with G1: 1
# 1282/2534
# Etls with M1: 0
# Htls with M1: 1
# 1285/2534
# Etls with SnO: 1
# Htls with SnO: 0
# 1286/2534
# Etls with JK-217D: 0
# Htls with JK-217D: 1
# 1293/2534
# Etls with 2F: 0
# Htls with 2F: 1
# 1294/2534
# Etls with C60-N: 17
# Htls with C60-N: 0
# 1295/2534
# Etls with CeO2-c: 2
# Htls with CeO2-c: 0
# 1296/2534
# Etls with 1,2-ethanedithiol: 4
# Htls with 1,2-ethanedithiol: 0
# 1301/2534
# Etls with B2T: 1
# Htls with B2T: 0
# 1303/2534
# Etls with PFN: 101
# Htls with PFN: 117
# 1308/2534
# Etls with DPPS: 0
# Htls with DPPS: 6
# 1311/2534
# Etls with Oleic-acid: 0
# Htls with Oleic-acid: 2
# 1317/2534
# Etls with ME3: 0
# Htls with ME3: 1
# 1319/2534
# Etls with Trimethylamine oxide: 7
# Htls with Trimethylamine oxide: 0
# 1320/2534
# Etls with Oleylamine: 0
# Htls with Oleylamine: 2
# 1323/2534
# Etls with ZnPy: 0
# Htls with ZnPy: 2
# 1324/2534
# Etls with TiO2-nt: 58
# Htls with TiO2-nt: 0
# 1327/2534
# Etls with ZnS: 5
# Htls with ZnS: 0
# 1328/2534
# Etls with AZ2: 0
# Htls with AZ2: 1
# 1329/2534
# Etls with PTAA: 16
# Htls with PTAA: 2323
# 1332/2534
# Etls with PCE-10: 0
# Htls with PCE-10: 4
# 1333/2534
# Etls with NDT: 0
# Htls with NDT: 1
# 1336/2534
# Etls with Carbozole @ S14: 0
# Htls with Carbozole @ S14: 4
# 1339/2534
# Etls with PPDI: 0
# Htls with PPDI: 3
# 1346/2534
# Etls with V1013: 0
# Htls with V1013: 1
# 1348/2534
# Etls with NiO-np: 24
# Htls with NiO-np: 475
# 1364/2534
# Etls with P3HT-MoS2: 0
# Htls with P3HT-MoS2: 1
# 1365/2534
# Etls with FH-3: 0
# Htls with FH-3: 1
# 1366/2534
# Etls with La2O3: 1
# Htls with La2O3: 0
# 1368/2534
# Etls with 2H-MoS2: 0
# Htls with 2H-MoS2: 1
# 1373/2534
# Etls with Spiro-TTB: 0
# Htls with Spiro-TTB: 18
# 1376/2534
# Etls with YT1: 0
# Htls with YT1: 1
# 1377/2534
# Etls with s-PANI:PSS: 0
# Htls with s-PANI:PSS: 4
# 1379/2534
# Etls with HATNA-F6: 1
# Htls with HATNA-F6: 0
# 1383/2534
# Etls with GaN: 4
# Htls with GaN: 0
# 1385/2534
# Etls with C60: 3868
# Htls with C60: 8
# 1390/2534
# Etls with P1: 1
# Htls with P1: 13
# 1395/2534
# Etls with Carbon-QDs: 32
# Htls with Carbon-QDs: 5
# 1396/2534
# Etls with Acetyl acetate: 1
# Htls with Acetyl acetate: 0
# 1398/2534
# Etls with Perylene: 0
# Htls with Perylene: 9
# 1401/2534
# Etls with PTCA: 5
# Htls with PTCA: 0
# 1402/2534
# Etls with EMIM-PF6: 1
# Htls with EMIM-PF6: 0
# 1405/2534
# Etls with V1225: 0
# Htls with V1225: 1
# 1408/2534
# Etls with Red Phosphorous-QDs: 0
# Htls with Red Phosphorous-QDs: 2
# 1409/2534
# Etls with F33: 0
# Htls with F33: 1
# 1410/2534
# Etls with Propionic acid: 0
# Htls with Propionic acid: 2
# 1412/2534
# Etls with Montmorillonite: 0
# Htls with Montmorillonite: 4
# 1422/2534
# Etls with MABr: 1
# Htls with MABr: 0
# 1425/2534
# Etls with bis-PCBM: 2
# Htls with bis-PCBM: 0
# 1428/2534
# Etls with CdI2: 1
# Htls with CdI2: 0
# 1431/2534
# Etls with GAN: 4
# Htls with GAN: 0
# 1432/2534
# Etls with DTS: 0
# Htls with DTS: 7
# 1433/2534
# Etls with XDB: 0
# Htls with XDB: 2
# 1440/2534
# Etls with P-R: 0
# Htls with P-R: 2
# 1441/2534
# Etls with Glycerol: 0
# Htls with Glycerol: 1
# 1443/2534
# Etls with GD: 0
# Htls with GD: 1
# 1444/2534
# Etls with [BMIM]BF4: 8
# Htls with [BMIM]BF4: 0
# 1445/2534
# Etls with SM-1: 0
# Htls with SM-1: 1
# 1448/2534
# Etls with HAT-CN: 1
# Htls with HAT-CN: 5
# 1449/2534
# Etls with Na2SO4: 11
# Htls with Na2SO4: 0
# 1452/2534
# Etls with M104: 0
# Htls with M104: 4
# 1453/2534
# Etls with H7: 0
# Htls with H7: 2
# 1457/2534
# Etls with Cysteine: 0
# Htls with Cysteine: 2
# 1460/2534
# Etls with LiTFSI: 0
# Htls with LiTFSI: 1
# 1462/2534
# Etls with SnO2: 104
# Htls with SnO2: 1
# 1463/2534
# Etls with MoOx: 3
# Htls with MoOx: 75
# 1464/2534
# Etls with Propylene carbonate: 0
# Htls with Propylene carbonate: 0
# 1466/2534
# Etls with MEH: 0
# Htls with MEH: 1
# 1470/2534
# Etls with Z3: 0
# Htls with Z3: 1
# 1472/2534
# Etls with TDAC: 0
# Htls with TDAC: 1
# 1475/2534
# Etls with 1-OMe-SAM: 1
# Htls with 1-OMe-SAM: 0
# 1477/2534
# Etls with PANI:PSS: 0
# Htls with PANI:PSS: 4
# 1483/2534
# Etls with MPA: 0
# Htls with MPA: 1
# 1484/2534
# Etls with Z1012: 0
# Htls with Z1012: 1
# 1485/2534
# Etls with PFI: 0
# Htls with PFI: 1
# 1486/2534
# Etls with SnO2-np: 2101
# Htls with SnO2-np: 0
# 1488/2534
# Etls with SO7: 0
# Htls with SO7: 1
# 1489/2534
# Etls with CsCl: 1
# Htls with CsCl: 0
# 1495/2534
# Etls with YT4: 0
# Htls with YT4: 1
# 1497/2534
# Etls with Spiro-TAD: 0
# Htls with Spiro-TAD: 3
# 1498/2534
# Etls with MeO-2PACZ: 0
# Htls with MeO-2PACZ: 2
# 1500/2534
# Etls with SrTiO3:TiO2-mp: 3
# Htls with SrTiO3:TiO2-mp: 0
# 1512/2534
# Etls with BaSnO3-mp: 3
# Htls with BaSnO3-mp: 0
# 1513/2534
# Etls with CMB: 2
# Htls with CMB: 0
# 1517/2534
# Etls with FeO: 4
# Htls with FeO: 0
# 1518/2534
# Etls with SiO2-mp: 33
# Htls with SiO2-mp: 0
# 1520/2534
# Etls with Al2O3-mp: 459
# Htls with Al2O3-mp: 45
# 1531/2534
# Etls with TmPyPB: 21
# Htls with TmPyPB: 0
# 1541/2534
# Etls with V2O5: 0
# Htls with V2O5: 19
# 1545/2534
# Etls with D35: 2
# Htls with D35: 0
# 1548/2534
# Etls with TPL: 0
# Htls with TPL: 1
# 1550/2534
# Etls with HPDI: 0
# Htls with HPDI: 2
# 1551/2534
# Etls with NPB: 0
# Htls with NPB: 30
# 1553/2534
# Etls with TMTA: 2
# Htls with TMTA: 0
# 1555/2534
# Etls with Q205: 0
# Htls with Q205: 1
# 1557/2534
# Etls with PDMS: 0
# Htls with PDMS: 3
# 1558/2534
# Etls with DS1: 1
# Htls with DS1: 0
# 1562/2534
# Etls with Z30: 0
# Htls with Z30: 1
# 1567/2534
# Etls with BACl: 22
# Htls with BACl: 0
# 1571/2534
# Etls with M112: 0
# Htls with M112: 1
# 1572/2534
# Etls with FDA: 1
# Htls with FDA: 4
# 1574/2534
# Etls with Fe2O3: 18
# Htls with Fe2O3: 0
# 1579/2534
# Etls with pFN-Br: 3
# Htls with pFN-Br: 0
# 1582/2534
# Etls with Rhodamine 101: 175
# Htls with Rhodamine 101: 0
# 1583/2534
# Etls with P3HT: 5
# Htls with P3HT: 964
# 1586/2534
# Etls with NDI: 6
# Htls with NDI: 0
# 1590/2534
# Etls with YN3: 0
# Htls with YN3: 2
# 1591/2534
# Etls with CuI: 3
# Htls with CuI: 108
# 1593/2534
# Etls with Black phosphorous nanosheets: 0
# Htls with Black phosphorous nanosheets: 3
# 1594/2534
# Etls with PTh: 0
# Htls with PTh: 1
# 1598/2534
# Etls with PCBB: 2
# Htls with PCBB: 0
# 1599/2534
# Etls with 2-MP: 0
# Htls with 2-MP: 2
# 1603/2534
# Etls with CPTA: 53
# Htls with CPTA: 0
# 1606/2534
# Etls with Q216: 0
# Htls with Q216: 2
# 1609/2534
# Etls with PSS: 7
# Htls with PSS: 7
# 1614/2534
# Etls with P3OT: 0
# Htls with P3OT: 2
# 1621/2534
# Etls with Caffeine: 0
# Htls with Caffeine: 1
# 1623/2534
# Etls with H11: 0
# Htls with H11: 1
# 1626/2534
# Etls with YT3: 0
# Htls with YT3: 1
# 1629/2534
# Etls with Polythiophene: 0
# Htls with Polythiophene: 6
# 1635/2534
# Etls with PEO: 0
# Htls with PEO: 7
# 1642/2534
# Etls with TPPO: 2
# Htls with TPPO: 0
# 1647/2534
# Etls with PbPc: 0
# Htls with PbPc: 3
# 1648/2534
# Etls with PFN-Br: 17
# Htls with PFN-Br: 21
# 1653/2534
# Etls with M114: 0
# Htls with M114: 1
# 1655/2534
# Etls with NaYF4:Yb:Er-np: 5
# Htls with NaYF4:Yb:Er-np: 2
# 1657/2534
# Etls with Z8: 0
# Htls with Z8: 1
# 1659/2534
# Etls with BTPA: 0
# Htls with BTPA: 3
# 1661/2534
# Etls with PAS: 0
# Htls with PAS: 2
# 1666/2534
# Etls with Zr(acac)4: 133
# Htls with Zr(acac)4: 2
# 1669/2534
# Etls with CeOx: 9
# Htls with CeOx: 0
# 1673/2534
# Etls with Carbon-nt: 6
# Htls with Carbon-nt: 30
# 1675/2534
# Etls with X54: 0
# Htls with X54: 1
# 1677/2534
# Etls with V1091: 0
# Htls with V1091: 2
# 1678/2534
# Etls with 4PA-SAM: 1
# Htls with 4PA-SAM: 0
# 1683/2534
# Etls with HL-2: 0
# Htls with HL-2: 3
# 1684/2534
# Etls with Adamantane: 0
# Htls with Adamantane: 1
# 1686/2534
# Etls with PDCBT: 0
# Htls with PDCBT: 26
# 1688/2534
# Etls with Zn(acac)2: 6
# Htls with Zn(acac)2: 0
# 1690/2534
# Etls with Theobromine: 0
# Htls with Theobromine: 1
# 1698/2534
# Etls with H66: 0
# Htls with H66: 2
# 1699/2534
# Etls with X62: 0
# Htls with X62: 1
# 1700/2534
# Etls with Pentacene: 0
# Htls with Pentacene: 1
# 1701/2534
# Etls with H2Pc: 0
# Htls with H2Pc: 3
# 1703/2534
# Etls with JW6: 0
# Htls with JW6: 1
# 1704/2534
# Etls with NO-Graphene-QDs: 0
# Htls with NO-Graphene-QDs: 2
# 1706/2534
# Etls with PMMA: 3
# Htls with PMMA: 85
# 1708/2534
# Etls with 1d @ triphenylamine modified azobenzene dyes: 0
# Htls with 1d @ triphenylamine modified azobenzene dyes: 1
# 1712/2534
# Etls with NiS: 0
# Htls with NiS: 1
# 1716/2534
# Etls with F4-TCNQ: 0
# Htls with F4-TCNQ: 5
# 1717/2534
# Etls with PN: 1
# Htls with PN: 0
# 1724/2534
# Etls with Ethanol amine: 3
# Htls with Ethanol amine: 0
# 1728/2534
# Etls with ZnO: 101
# Htls with ZnO: 0
# 1729/2534
# Etls with TBP: 0
# Htls with TBP: 2
# 1731/2534
# Etls with V1004: 0
# Htls with V1004: 1
# 1736/2534
# Etls with V886: 0
# Htls with V886: 1
# 1737/2534
# Etls with 3-Methylthiophene: 0
# Htls with 3-Methylthiophene: 4
# 1741/2534
# Etls with Methoxypropionitrile: 0
# Htls with Methoxypropionitrile: 0
# 1743/2534
# Etls with CMP: 0
# Htls with CMP: 1
# 1744/2534
# Etls with TIPS-pentacene: 0
# Htls with TIPS-pentacene: 2
# 1746/2534
# Etls with Methoxyacetonitrile: 0
# Htls with Methoxyacetonitrile: 0
# 1747/2534
# Etls with Selenium: 0
# Htls with Selenium: 2
# 1748/2534
# Etls with Acetonitrile: 0
# Htls with Acetonitrile: 3
# 1750/2534
# Etls with J1: 0
# Htls with J1: 1
# 1752/2534
# Etls with Grafted rGO: 0
# Htls with Grafted rGO: 2
# 1760/2534
# Etls with Ta:WOx: 0
# Htls with Ta:WOx: 1
# 1763/2534
# Etls with H111: 0
# Htls with H111: 2
# 1774/2534
# Etls with SnO2-nanosheets: 9
# Htls with SnO2-nanosheets: 0
# 1776/2534
# Etls with (3-Aminopropyl)trimethoxysilane: 2
# Htls with (3-Aminopropyl)trimethoxysilane: 0
# 1779/2534
# Etls with F4TCNQ: 0
# Htls with F4TCNQ: 3
# 1783/2534
# Etls with AAO: 19
# Htls with AAO: 0
# 1791/2534
# Etls with M108: 0
# Htls with M108: 2
# 1803/2534
# Etls with TFAP: 0
# Htls with TFAP: 1
# 1809/2534
# Etls with PolyTPD: 1
# Htls with PolyTPD: 176
# 1815/2534
# Etls with H65: 0
# Htls with H65: 2
# 1817/2534
# Etls with TiO2-mp: 13401
# Htls with TiO2-mp: 0
# 1822/2534
# Etls with MK2: 1
# Htls with MK2: 0
# 1829/2534
# Etls with ZnCdS: 1
# Htls with ZnCdS: 0
# 1833/2534
# Etls with SAED: 1
# Htls with SAED: 0
# 1834/2534
# Etls with SnO2-QDs: 37
# Htls with SnO2-QDs: 0
# 1835/2534
# Etls with TET: 0
# Htls with TET: 2
# 1836/2534
# Etls with Zeocoat: 0
# Htls with Zeocoat: 1
# 1837/2534
# Etls with ITO: 20
# Htls with ITO: 4
# 1838/2534
# Etls with PTEG-1: 16
# Htls with PTEG-1: 0
# 1839/2534
# Etls with PTB7-Th: 0
# Htls with PTB7-Th: 6
# 1840/2534
# Etls with NTPA: 0
# Htls with NTPA: 1
# 1846/2534
# Etls with FU7: 0
# Htls with FU7: 5
# 1848/2534
# Etls with p-amino-benzoic acid: 2
# Htls with p-amino-benzoic acid: 0
# 1849/2534
# Etls with UiO-66: 0
# Htls with UiO-66: 1
# 1852/2534
# Etls with BuO-DATPA: 0
# Htls with BuO-DATPA: 1
# 1853/2534
# Etls with 1ab: 0
# Htls with 1ab: 3
# 1858/2534
# Etls with TaTM: 0
# Htls with TaTM: 6
# 1860/2534
# Etls with M105: 0
# Htls with M105: 2
# 1861/2534
# Etls with DEH: 0
# Htls with DEH: 1
# 1866/2534
# Etls with TPE-4DPA: 0
# Htls with TPE-4DPA: 3
# 1867/2534
# Etls with PFB: 0
# Htls with PFB: 11
# 1873/2534
# Etls with ZnO-nanospheres: 11
# Htls with ZnO-nanospheres: 0
# 1875/2534
# Etls with COi8DFIC: 1
# Htls with COi8DFIC: 0
# 1879/2534
# Etls with C3-SAM: 2
# Htls with C3-SAM: 0
# 1880/2534
# Etls with V1061: 0
# Htls with V1061: 1
# 1882/2534
# Etls with Al203-c: 1
# Htls with Al203-c: 0
# 1883/2534
# Etls with MnS: 0
# Htls with MnS: 7
# 1885/2534
# Etls with TQ2: 0
# Htls with TQ2: 2
# 1887/2534
# Etls with M117: 0
# Htls with M117: 1
# 1888/2534
# Etls with CMO: 0
# Htls with CMO: 5
# 1889/2534
# Etls with V1050: 0
# Htls with V1050: 1
# 1891/2534
# Etls with graphite nanofibers: 1
# Htls with graphite nanofibers: 0
# 1897/2534
# Etls with F6-TCNNQ: 0
# Htls with F6-TCNNQ: 54
# 1906/2534
# Etls with TQ1: 0
# Htls with TQ1: 9
# 1908/2534
# Etls with ATTA: 1
# Htls with ATTA: 0
# 1909/2534
# Etls with JW7: 0
# Htls with JW7: 1
# 1912/2534
# Etls with BT: 0
# Htls with BT: 1
# 1914/2534
# Etls with Ir(MDQ)2(acac): 0
# Htls with Ir(MDQ)2(acac): 0
# 1915/2534
# Etls with V1221: 0
# Htls with V1221: 1
# 1919/2534
# Etls with Caproic acid: 1
# Htls with Caproic acid: 0
# 1920/2534
# Etls with C101: 0
# Htls with C101: 1
# 1927/2534
# Etls with X23: 0
# Htls with X23: 1
# 1929/2534
# Etls with KOH: 1
# Htls with KOH: 0
# 1930/2534
# Etls with T103: 0
# Htls with T103: 1
# 1934/2534
# Etls with Fluorosilane: 1
# Htls with Fluorosilane: 0
# 1939/2534
# Etls with 4-methoxybenzoic acid: 2
# Htls with 4-methoxybenzoic acid: 0
# 1941/2534
# Etls with Carbon: 6
# Htls with Carbon: 25
# 1942/2534
# Etls with PTQ10: 0
# Htls with PTQ10: 3
# 1944/2534
# Etls with NaI: 0
# Htls with NaI: 1
# 1945/2534
# Etls with Y1: 0
# Htls with Y1: 1
# 1946/2534
# Etls with 3TPYMB: 3
# Htls with 3TPYMB: 0
# 1953/2534
# Etls with DM2: 0
# Htls with DM2: 1
# 1955/2534
# Etls with TiO2-nw: 435
# Htls with TiO2-nw: 0
# 1956/2534
# Etls with ICBA: 48
# Htls with ICBA: 0
# 1957/2534
# Etls with KCl: 17
# Htls with KCl: 2
# 1958/2534
# Etls with Pbs-QDs: 5
# Htls with Pbs-QDs: 0
# 1960/2534
# Etls with PbSe: 2
# Htls with PbSe: 0
# 1961/2534
# Etls with H-Bi: 0
# Htls with H-Bi: 1
# 1963/2534
# Etls with Poly-N-vinylcarbazole: 0
# Htls with Poly-N-vinylcarbazole: 3
# 1964/2534
# Etls with XY1: 0
# Htls with XY1: 8
# 1965/2534
# Etls with PDI: 5
# Htls with PDI: 3
# 1969/2534
# Etls with Ti: 12
# Htls with Ti: 0
# 1973/2534
# Etls with V1160: 0
# Htls with V1160: 3
# 1979/2534
# Etls with VO: 0
# Htls with VO: 2
# 1981/2534
# Etls with C102: 0
# Htls with C102: 1
# 1986/2534
# Etls with HL-1: 0
# Htls with HL-1: 2
# 1987/2534
# Etls with YD2-o-C8: 0
# Htls with YD2-o-C8: 1
# 1988/2534
# Etls with Q10: 2
# Htls with Q10: 0
# 1989/2534
# Etls with PNP: 3
# Htls with PNP: 0
# 1999/2534
# Etls with Al2O3-c: 57
# Htls with Al2O3-c: 31
# 2001/2534
# Etls with Porphyrin: 0
# Htls with Porphyrin: 2
# 2003/2534
# Etls with Zn2SnO4-mp: 8
# Htls with Zn2SnO4-mp: 0
# 2006/2534
# Etls with H18: 0
# Htls with H18: 1
# 2010/2534
# Etls with Ps: 4
# Htls with Ps: 0
# 2012/2534
# Etls with MeO-TPD: 0
# Htls with MeO-TPD: 15
# 2017/2534
# Etls with Diethanolamine: 0
# Htls with Diethanolamine: 2
# 2019/2534
# Etls with Nb2O5-c: 17
# Htls with Nb2O5-c: 0
# 2029/2534
# Etls with EtO-DATPA: 0
# Htls with EtO-DATPA: 1
# 2030/2534
# Etls with NH4Cl: 1
# Htls with NH4Cl: 0
# 2033/2534
# Etls with Q197: 0
# Htls with Q197: 1
# 2035/2534
# Etls with Z1013: 0
# Htls with Z1013: 1
# 2037/2534
# Etls with DTB: 0
# Htls with DTB: 8
# 2044/2534
# Etls with ZnP: 0
# Htls with ZnP: 2
# 2048/2534
# Etls with YR3: 0
# Htls with YR3: 2
# 2051/2534
# Etls with TEABr: 12
# Htls with TEABr: 0
# 2052/2534
# Etls with B58: 0
# Htls with B58: 1
# 2056/2534
# Etls with M115: 0
# Htls with M115: 1
# 2058/2534
# Etls with TiO2-nanobeads: 1
# Htls with TiO2-nanobeads: 0
# 2064/2534
# Etls with I2: 0
# Htls with I2: 4
# 2067/2534
# Etls with Carbo-QDs: 3
# Htls with Carbo-QDs: 0
# 2068/2534
# Etls with Lif: 5
# Htls with Lif: 0
# 2072/2534
# Etls with WO3: 34
# Htls with WO3: 28
# 2077/2534
# Etls with L-f: 0
# Htls with L-f: 1
# 2078/2534
# Etls with Al2O3: 11
# Htls with Al2O3: 10
# 2081/2534
# Etls with S2: 0
# Htls with S2: 1
# 2083/2534
# Etls with NiPc: 0
# Htls with NiPc: 14
# 2094/2534
# Etls with Ga2O3: 1
# Htls with Ga2O3: 0
# 2099/2534
# Etls with Z26: 0
# Htls with Z26: 2
# 2100/2534
# Etls with DMZ: 0
# Htls with DMZ: 13
# 2103/2534
# Etls with H16: 0
# Htls with H16: 1
# 2107/2534
# Etls with GeO2: 0
# Htls with GeO2: 8
# 2112/2534
# Etls with MEAI: 0
# Htls with MEAI: 3
# 2115/2534
# Etls with Sb2O3-np: 1
# Htls with Sb2O3-np: 0
# 2121/2534
# Etls with CrOx: 0
# Htls with CrOx: 4
# 2122/2534
# Etls with PTB7-th: 0
# Htls with PTB7-th: 1
# 2123/2534
# Etls with CuInSe2-QDss: 0
# Htls with CuInSe2-QDss: 1
# 2125/2534
# Etls with HA2: 0
# Htls with HA2: 2
# 2126/2534
# Etls with 5,6,11,12-Tetraphenylnaphthacene: 0
# Htls with 5,6,11,12-Tetraphenylnaphthacene: 2
# 2127/2534
# Etls with 3C: 0
# Htls with 3C: 1
# 2128/2534
# Etls with M118: 0
# Htls with M118: 1
# 2132/2534
# Etls with M4: 0
# Htls with M4: 2
# 2133/2534
# Etls with RCP: 0
# Htls with RCP: 4
# 2139/2534
# Etls with 1,2-diaminoethane: 1
# Htls with 1,2-diaminoethane: 0
# 2144/2534
# Etls with TPC: 0
# Htls with TPC: 1
# 2145/2534
# Etls with CuOx: 0
# Htls with CuOx: 26
# 2149/2534
# Etls with Polyethylene glycol: 0
# Htls with Polyethylene glycol: 0
# 2150/2534
# Etls with tBP: 0
# Htls with tBP: 1
# 2151/2534
# Etls with NiCl2: 4
# Htls with NiCl2: 0
# 2155/2534
# Etls with X2: 0
# Htls with X2: 7
# 2157/2534
# Etls with Benzylamine: 0
# Htls with Benzylamine: 1
# 2161/2534
# Etls with T102: 0
# Htls with T102: 1
# 2162/2534
# Etls with ZnSe: 12
# Htls with ZnSe: 0
# 2164/2534
# Etls with Carbozole @ S12: 0
# Htls with Carbozole @ S12: 4
# 2166/2534
# Etls with CdSe: 3
# Htls with CdSe: 0
# 2168/2534
# Etls with Ag-np: 24
# Htls with Ag-np: 4
# 2170/2534
# Etls with PO-T2T: 2
# Htls with PO-T2T: 0
# 2171/2534
# Etls with ZnO-nanofibers: 6
# Htls with ZnO-nanofibers: 0
# 2172/2534
# Etls with M110: 0
# Htls with M110: 2
# 2174/2534
# Etls with Nb2O5: 109
# Htls with Nb2O5: 0
# 2177/2534
# Etls with 3-Hexylthiophene: 0
# Htls with 3-Hexylthiophene: 4
# 2178/2534
# Etls with OEABS: 1
# Htls with OEABS: 0
# 2180/2534
# Etls with CuInS2: 3
# Htls with CuInS2: 14
# 2188/2534
# Etls with Z7: 0
# Htls with Z7: 1
# 2193/2534
# Etls with TTA: 0
# Htls with TTA: 1
# 2194/2534
# Etls with TPBi: 8
# Htls with TPBi: 3
# 2195/2534
# Etls with OAI: 0
# Htls with OAI: 3
# 2198/2534
# Etls with n-octylammonium iodide: 0
# Htls with n-octylammonium iodide: 1
# 2200/2534
# Etls with In2O3: 21
# Htls with In2O3: 4
# 2202/2534
# Etls with H112: 0
# Htls with H112: 2
# 2206/2534
# Etls with MDMO-PPV: 0
# Htls with MDMO-PPV: 2
# 2212/2534
# Etls with Bi2Te3: 0
# Htls with Bi2Te3: 3
# 2213/2534
# Etls with DM: 0
# Htls with DM: 17
# 2215/2534
# Etls with Z2: 0
# Htls with Z2: 3
# 2216/2534
# Etls with TcTa: 0
# Htls with TcTa: 1
# 2220/2534
# Etls with TiO2-np: 408
# Htls with TiO2-np: 1
# 2221/2534
# Etls with 2-OMe-SAM: 1
# Htls with 2-OMe-SAM: 0
# 2224/2534
# Etls with M2: 0
# Htls with M2: 2
# 2227/2534
# Etls with ITIC: 25
# Htls with ITIC: 7
# 2231/2534
# Etls with PQT-12: 0
# Htls with PQT-12: 2
# 2232/2534
# Etls with Rubene: 0
# Htls with Rubene: 2
# 2234/2534
# Etls with SY4: 0
# Htls with SY4: 5
# 2235/2534
# Etls with EGME: 1
# Htls with EGME: 0
# 2237/2534
# Etls with LiSPS: 7
# Htls with LiSPS: 0
# 2238/2534
# Etls with D103: 0
# Htls with D103: 1
# 2239/2534
# Etls with Phenethylamine: 0
# Htls with Phenethylamine: 1
# 2240/2534
# Etls with A101: 0
# Htls with A101: 13
# 2246/2534
# Etls with M7-TFSI: 0
# Htls with M7-TFSI: 1
# 2248/2534
# Etls with CaTiO3-c: 1
# Htls with CaTiO3-c: 0
# 2251/2534
# Etls with TPBS: 0
# Htls with TPBS: 2
# 2252/2534
# Etls with HTAB: 1
# Htls with HTAB: 0
# 2253/2534
# Etls with J2: 0
# Htls with J2: 1
# 2257/2534
# Etls with VOx: 0
# Htls with VOx: 48
# 2259/2534
# Etls with Imidazolium iodide: 0
# Htls with Imidazolium iodide: 1
# 2260/2534
# Etls with TZ-3: 0
# Htls with TZ-3: 0
# 2263/2534
# Etls with PMT: 0
# Htls with PMT: 1
# 2269/2534
# Etls with PVK: 0
# Htls with PVK: 5
# 2273/2534
# Etls with c-TCTA: 0
# Htls with c-TCTA: 8
# 2275/2534
# Etls with PPN: 0
# Htls with PPN: 1
# 2276/2534
# Etls with SM13: 0
# Htls with SM13: 2
# 2279/2534
# Etls with PPV: 0
# Htls with PPV: 1
# 2292/2534
# Etls with DS2: 1
# Htls with DS2: 0
# 2293/2534
# Etls with SeS2: 0
# Htls with SeS2: 0
# 2294/2534
# Etls with H64: 0
# Htls with H64: 2
# 2302/2534
# Etls with PEI: 336
# Htls with PEI: 17
# 2303/2534
# Etls with M106: 0
# Htls with M106: 2
# 2304/2534
# Etls with Ag: 8
# Htls with Ag: 0
# 2308/2534
# Etls with CuIn1.5Se3-QDs: 0
# Htls with CuIn1.5Se3-QDs: 8
# 2313/2534
# Etls with FeS2: 0
# Htls with FeS2: 1
# 2314/2534
# Etls with CuPc: 0
# Htls with CuPc: 146
# 2317/2534
# Etls with BPB-M: 1
# Htls with BPB-M: 0
# 2325/2534
# Etls with PTCDA: 2
# Htls with PTCDA: 0
# 2327/2534
# Etls with C60-SAM: 144
# Htls with C60-SAM: 0
# 2333/2534
# Etls with pentaerythritol tetrakis(3-mercaptopropionate): 0
# Htls with pentaerythritol tetrakis(3-mercaptopropionate): 2
# 2334/2534
# Etls with n-Butylamine: 0
# Htls with n-Butylamine: 5
# 2335/2534
# Etls with Me-4PACz: 0
# Htls with Me-4PACz: 2
# 2336/2534
# Etls with Aniline: 1
# Htls with Aniline: 1
# 2337/2534
# Etls with TPTPA: 0
# Htls with TPTPA: 21
# 2338/2534
# Etls with YK2: 0
# Htls with YK2: 2
# 2340/2534
# Etls with CTAB: 1
# Htls with CTAB: 7
# 2346/2534
# Etls with TAE: 0
# Htls with TAE: 5
# 2347/2534
# Etls with PDQT: 0
# Htls with PDQT: 2
# 2350/2534
# Etls with CzP: 0
# Htls with CzP: 1
# 2355/2534
# Etls with Spiro-MeOTAD: 0
# Htls with Spiro-MeOTAD: 21737
# 2358/2534
# Etls with M6: 0
# Htls with M6: 1
# 2359/2534
# Etls with Teflon: 1
# Htls with Teflon: 0
# 2362/2534
# Etls with 2-acetylpyridine: 4
# Htls with 2-acetylpyridine: 0
# 2366/2534
# Etls with ZnNc: 0
# Htls with ZnNc: 1
# 2370/2534
# Etls with M102: 0
# Htls with M102: 2
# 2375/2534
# Etls with JW8: 0
# Htls with JW8: 1
# 2376/2534
# Etls with Z1011: 0
# Htls with Z1011: 2
# 2377/2534
# Etls with X51: 0
# Htls with X51: 4
# 2378/2534
# Etls with DPO: 8
# Htls with DPO: 0
# 2379/2534
# Etls with MeO-2PACz: 0
# Htls with MeO-2PACz: 8
# 2380/2534
# Etls with VNPB: 1
# Htls with VNPB: 4
# 2382/2534
# Etls with 2H-TaS2: 1
# Htls with 2H-TaS2: 0
# 2383/2534
# Etls with DMF: 1
# Htls with DMF: 5
# 2384/2534
# Etls with G2: 0
# Htls with G2: 1
# 2389/2534
# Etls with ZnSO: 12
# Htls with ZnSO: 0
# 2393/2534
# Etls with MoS2-nanosheets: 4
# Htls with MoS2-nanosheets: 0
# 2397/2534
# Etls with Graphitic carbon nitride: 3
# Htls with Graphitic carbon nitride: 0
# 2398/2534
# Etls with H-FL: 0
# Htls with H-FL: 1
# 2404/2534
# Etls with LiBr: 0
# Htls with LiBr: 0
# 2406/2534
# Etls with PbI2: 7
# Htls with PbI2: 1
# 2413/2534
# Etls with Zn2SnO4-c: 13
# Htls with Zn2SnO4-c: 0
# 2414/2534
# Etls with Z10: 0
# Htls with Z10: 1
# 2415/2534
# Etls with SP-12: 0
# Htls with SP-12: 2
# 2417/2534
# Etls with PTA: 0
# Htls with PTA: 11
# 2419/2534
# Etls with Bi2S3: 1
# Htls with Bi2S3: 0
# 2421/2534
# Etls with Aminocaproic acid: 4
# Htls with Aminocaproic acid: 0
# 2424/2534
# Etls with TEAI: 14
# Htls with TEAI: 0
# 2431/2534
# Etls with Tetracene: 0
# Htls with Tetracene: 2
# 2432/2534
# Etls with C12H10B2O4: 0
# Htls with C12H10B2O4: 1
# 2438/2534
# Etls with MgO: 48
# Htls with MgO: 0
# 2444/2534
# Etls with Choline Chloride: 2
# Htls with Choline Chloride: 0
# 2448/2534
# Etls with none: 281
# Htls with none: 2626
# 2450/2534

# %%
print(f"ETL identified materials appearances: {sum_etl}")
print(f"HTL identified materials appearances: {sum_htl}")
# Out:
# ETL identified materials appearances: 70253
# HTL identified materials appearances: 41781

# %% [markdown]
# ## Unidentified materials: How many cells pertain to each?
#
# This is interesting to see if there are unidentified materials which are used in many cells. In such cases it might be worth the time to identify them manually.

# %%
# Construct dataframe of unidentified materials and their frequency
unidentified_materials = []
no_cells = []

for index, row in df_new.iterrows():
    if pd.isna(row['CID']):
        unidentified_materials.append(row['Material'])
        no_cells.append(len(row['etl']) + len(row['htl']))

df_unid = pd.DataFrame({'Material': unidentified_materials, 'Cell_amount': no_cells})

# %%
# save into excel file
df_unid.sort_values(by = 'Cell_amount', ascending=False).to_excel('excel_tables/unidentified.xlsx', sheet_name='Unidentified')

# %%
df_unid.sort_values(by = 'Cell_amount', ascending=False).head(40)
# Out:
#                     Material  Cell_amount
# 1344                    PEIE          173
# 530                  NiMgLiO          161
# 1090                 P3CT-Na          136
# 826                    PEDOT           60
# 447                   P3CT-N           57
# 500                     PEAI           50
# 34                      P3CT           41
# 791                     TIPD           36
# 752                NiMgLiO-c           33
# 707                   P3CT-K           30
# 551             Graphene-QDs           30
# 250                     PTB7           30
# 814                   PCDTBT           30
# 545                   PDBD-T           29
# 432                    AZO-c           27
# 1369              CuPc(tBu)4           27
# 798                     TiS2           25
# 1590                  SrTiO3           25
# 33                 Carbon-mp           24
# 1186              asy-PBTBDT           24
# 476                  TS-CuPc           23
# 433                     PN4N           22
# 1245            BDTT:DPPD:TT           20
# 1558                    CZTS           20
# 342            P3TAA-co-P3HT           20
# 929                   CuCrO2           20
# 358             Co-Porphyrin           20
# 1110                  BDT:TT           20
# 532            Rodhamine 101           19
# 1232                  PFN-P2           19
# 1020                  CZ-STA           18
# 429                  CeOx-np           18
# 489                      XPP           18
# 280           Spiro p-xylene           18
# 732                    NDP-V           18
# 773       Florinated polymer           18
# 1364                   PCBSD           16
# 665   Poly(3-bromothiophene)           16
# 199                ITCPTC-Th           16
# 1115                 p-PFP-O           16

# %% [markdown]
# # Create Excel Sheet for manual evaluation

# %%
ref_list_etl = []
ref_list_htl = []

for rowindex, row in df_new.iterrows():
    #etl
    minilist = []
    for index, cell_index in enumerate(row['etl']):
        minilist.append(df_all_ctls['ref'].iloc[cell_index])
    ref_list_etl.append(minilist)
    
    # htl
    minilist = []
    for index, cell_index in enumerate(row['htl']):
        minilist.append(df_all_ctls['ref'].iloc[cell_index])
    ref_list_htl.append(minilist)


df_new['etl_refs'] = ref_list_etl
df_new['htl_refs'] = ref_list_htl

# %%
evaluation_df = df_new.drop(columns=['etl',
                                     'htl'])

evaluation_df = evaluation_df.dropna(subset=['CID'])
evaluation_df['CID'] = evaluation_df['CID'].astype(int)

# %%
# draw 100 at random 
all_samples = evaluation_df.sample(800, random_state=42)

# split into evaluation batches of 10
samples = [all_samples.iloc[10*i:10*i+10] for i in range(10)]

# %%
with pd.ExcelWriter("excel_tables/human_evaluation.xlsx") as writer:

    for index, sample in enumerate(samples):
        sample.to_excel(writer, sheet_name=f"Sample {index+1}", index=False)

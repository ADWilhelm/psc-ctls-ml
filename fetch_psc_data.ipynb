# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Fetching data

# %%
# Function to extract values from the downloaded entries
def extract_values(entry):
    try:
        htl.append(entry['results']['properties']['optoelectronic']['solar_cell']['hole_transport_layer'])
    except:
        htl.append('None')
    try:
        etl.append(entry['results']['properties']['optoelectronic']['solar_cell']['electron_transport_layer'])
    except:
        etl.append('None')
    try:
        pce.append(entry['results']['properties']['optoelectronic']['solar_cell']['efficiency'])
    except:
        pce.append('None')
    return htl, etl, pce

# %%
# gets the data from NOMAD

import requests

htl = []
etl = []
pce = []
page_after_value = None
base_url = 'https://nomad-lab.eu/prod/v1/api/v1/'

while True:
    data = requests.post(f'{base_url}entries/query', json={
        "owner": "visible",
        "aggregations": {},
        "query": {
            "and": [
                {"results.material.elements:all": ["*"]}, 
                {"sections:all": ["nomad.datamodel.results.SolarCell"]},
                ]},
        "required": {
            "results":{
                "material": {
                    "chemical_formula_reduced":"*",
                    "structural_type":"*"},
                "properties": {
                   "optoelectronic":{
                      "band_gap":"*",
                      "solar_cell":{
                          "open_circuit_voltage":"*",
                          "short_circuit_current_density":"*",
                          "fill_factor":"*",
                          "efficiency":"*",
                          }}},},
        },
        "pagination": {"page_size": 10,
                       "page_after_value": page_after_value}
        }).json()
    if not data['data']:
        break
    if 'next_page_after_value' not in data['pagination'].keys():
      # make sure to grasp the entries of the last page before breaking
      for entry in data['data']:
        if 'results' not in entry.keys():
          continue
        elif 'chemical_formula_reduced' not in entry['results']['material'].keys():
          continue
        else:
          extract_values(entry)
      break
    page_after_value = data['pagination']['next_page_after_value']

    for entry in data['data']:
      if 'results' not in entry.keys():
        continue
      elif 'chemical_formula_reduced' not in entry['results']['material'].keys():
        continue
      else:
        extract_values(entry)

# %%
# look at the the entry
entry
# Out:
# {'upload_id': 'FT8UX98FS5KtDbNBw-dU3A',
#  'references': ['https://doi.org/10.1016/j.matchemphys.2019.122310',
#   'https://doi.org/10.1038/s41560-021-00941-3',
#   'https://www.perovskitedatabase.com/'],
#  'origin': 'The Perovskite Database Project',
#  'quantities': ['',
#   'data',
#   'data.add',
#   'data.add.lay_back',
#   'data.add.lay_back_deposition_aggregation_state_of_reactants',
#   'data.add.lay_back_deposition_procedure',
#   'data.add.lay_back_deposition_reaction_solutions_age',
#   'data.add.lay_back_deposition_reaction_solutions_compounds_purity',
#   'data.add.lay_back_deposition_reaction_solutions_compounds_supplier',
#   'data.add.lay_back_deposition_reaction_solutions_temperature',
#   'data.add.lay_back_deposition_reaction_solutions_volumes',
#   'data.add.lay_back_deposition_solvents',
#   'data.add.lay_back_deposition_solvents_purity',
#   'data.add.lay_back_deposition_solvents_supplier',
#   'data.add.lay_back_deposition_substrate_temperature',
#   'data.add.lay_back_deposition_synthesis_atmosphere',
#   'data.add.lay_back_deposition_thermal_annealing_atmosphere',
#   'data.add.lay_back_deposition_thermal_annealing_temperature',
#   'data.add.lay_back_deposition_thermal_annealing_time',
#   'data.add.lay_back_stack_sequence',
#   'data.add.lay_back_storage_atmosphere',
#   'data.add.lay_back_storage_time_until_next_deposition_step',
#   'data.add.lay_front',
#   'data.add.lay_front_deposition_aggregation_state_of_reactants',
#   'data.add.lay_front_deposition_procedure',
#   'data.add.lay_front_deposition_reaction_solutions_age',
#   'data.add.lay_front_deposition_reaction_solutions_compounds_purity',
#   'data.add.lay_front_deposition_reaction_solutions_compounds_supplier',
#   'data.add.lay_front_deposition_reaction_solutions_temperature',
#   'data.add.lay_front_deposition_reaction_solutions_volumes',
#   'data.add.lay_front_deposition_solvents',
#   'data.add.lay_front_deposition_solvents_purity',
#   'data.add.lay_front_deposition_solvents_supplier',
#   'data.add.lay_front_deposition_substrate_temperature',
#   'data.add.lay_front_deposition_synthesis_atmosphere',
#   'data.add.lay_front_deposition_thermal_annealing_atmosphere',
#   'data.add.lay_front_deposition_thermal_annealing_temperature',
#   'data.add.lay_front_deposition_thermal_annealing_time',
#   'data.add.lay_front_stack_sequence',
#   'data.add.lay_front_storage_atmosphere',
#   'data.add.lay_front_storage_time_until_next_deposition_step',
#   'data.backcontact',
#   'data.backcontact.deposition_aggregation_state_of_reactants',
#   'data.backcontact.deposition_procedure',
#   'data.backcontact.deposition_reaction_solutions_age',
#   'data.backcontact.deposition_reaction_solutions_compounds_purity',
#   'data.backcontact.deposition_reaction_solutions_compounds_supplier',
#   'data.backcontact.deposition_reaction_solutions_temperature',
#   'data.backcontact.deposition_reaction_solutions_volumes',
#   'data.backcontact.deposition_solvents',
#   'data.backcontact.deposition_solvents_purity',
#   'data.backcontact.deposition_solvents_supplier',
#   'data.backcontact.deposition_substrate_temperature',
#   'data.backcontact.deposition_synthesis_atmosphere',
#   'data.backcontact.deposition_thermal_annealing_atmosphere',
#   'data.backcontact.deposition_thermal_annealing_temperature',
#   'data.backcontact.deposition_thermal_annealing_time',
#   'data.backcontact.stack_sequence',
#   'data.backcontact.storage_atmosphere',
#   'data.backcontact.storage_time_until_next_deposition_step',
#   'data.cell',
#   'data.cell.architecture',
#   'data.cell.area_measured',
#   'data.cell.flexible',
#   'data.cell.number_of_cells_per_substrate',
#   'data.cell.semitransparent',
#   'data.cell.semitransparent_wavelength_range',
#   'data.cell.stack_sequence',
#   'data.encapsulation',
#   'data.encapsulation.Encapsulation',
#   'data.encapsulation.atmosphere_for_encapsulation',
#   'data.encapsulation.edge_sealing_materials',
#   'data.encapsulation.stack_sequence',
#   'data.eqe',
#   'data.eqe.measured',
#   'data.etl',
#   'data.etl.additives_compounds',
#   'data.etl.deposition_aggregation_state_of_reactants',
#   'data.etl.deposition_procedure',
#   'data.etl.deposition_reaction_solutions_age',
#   'data.etl.deposition_reaction_solutions_compounds_purity',
#   'data.etl.deposition_reaction_solutions_compounds_supplier',
#   'data.etl.deposition_reaction_solutions_temperature',
#   'data.etl.deposition_reaction_solutions_volumes',
#   'data.etl.deposition_solvents',
#   'data.etl.deposition_solvents_purity',
#   'data.etl.deposition_solvents_supplier',
#   'data.etl.deposition_substrate_temperature',
#   'data.etl.deposition_synthesis_atmosphere',
#   'data.etl.deposition_thermal_annealing_atmosphere',
#   'data.etl.deposition_thermal_annealing_temperature',
#   'data.etl.deposition_thermal_annealing_time',
#   'data.etl.stack_sequence',
#   'data.etl.storage_atmosphere',
#   'data.etl.thickness',
#   'data.htl',
#   'data.htl.deposition_aggregation_state_of_reactants',
#   'data.htl.deposition_procedure',
#   'data.htl.deposition_reaction_solutions_age',
#   'data.htl.deposition_reaction_solutions_compounds_purity',
#   'data.htl.deposition_reaction_solutions_compounds_supplier',
#   'data.htl.deposition_reaction_solutions_temperature',
#   'data.htl.deposition_reaction_solutions_volumes',
#   'data.htl.deposition_solvents',
#   'data.htl.deposition_solvents_purity',
#   'data.htl.deposition_solvents_supplier',
#   'data.htl.deposition_substrate_temperature',
#   'data.htl.deposition_synthesis_atmosphere',
#   'data.htl.deposition_thermal_annealing_atmosphere',
#   'data.htl.deposition_thermal_annealing_temperature',
#   'data.htl.deposition_thermal_annealing_time',
#   'data.htl.stack_sequence',
#   'data.htl.storage_atmosphere',
#   'data.htl.storage_time_until_next_deposition_step',
#   'data.jv',
#   'data.jv.average_over_n_number_of_cells',
#   'data.jv.certified_values',
#   'data.jv.default_FF',
#   'data.jv.default_FF_scan_direction',
#   'data.jv.default_Jsc',
#   'data.jv.default_Jsc_scan_direction',
#   'data.jv.default_PCE',
#   'data.jv.default_PCE_scan_direction',
#   'data.jv.default_Voc',
#   'data.jv.default_Voc_scan_direction',
#   'data.jv.light_intensity',
#   'data.jv.light_masked_cell',
#   'data.jv.light_spectra',
#   'data.jv.light_wavelength_range',
#   'data.jv.measured',
#   'data.jv.reverse_scan_FF',
#   'data.jv.reverse_scan_Jsc',
#   'data.jv.reverse_scan_PCE',
#   'data.jv.reverse_scan_Voc',
#   'data.jv.storage_age_of_cell',
#   'data.jv.storage_atmosphere',
#   'data.jv.test_atmosphere',
#   'data.module',
#   'data.module.JV_data_recalculated_per_cell',
#   'data.module.Module',
#   'data.module.number_of_cells_in_module',
#   'data.outdoor',
#   'data.outdoor.PCE_burn_in_observed',
#   'data.outdoor.average_over_n_number_of_cells',
#   'data.outdoor.detaild_weather_data_available',
#   'data.outdoor.installation_number_of_solar_tracking_axis',
#   'data.outdoor.irradiance_measured',
#   'data.outdoor.location_coordinates',
#   'data.outdoor.periodic_JV_measurements',
#   'data.outdoor.potential_bias_range',
#   'data.outdoor.spectral_data_available',
#   'data.outdoor.temperature_range',
#   'data.outdoor.tested',
#   'data.outdoor.time_end',
#   'data.outdoor.time_start',
#   'data.perovskite',
#   'data.perovskite.additives_compounds',
#   'data.perovskite.band_gap_graded',
#   'data.perovskite.composition_a_ions',
#   'data.perovskite.composition_a_ions_coefficients',
#   'data.perovskite.composition_b_ions',
#   'data.perovskite.composition_b_ions_coefficients',
#   'data.perovskite.composition_c_ions',
#   'data.perovskite.composition_c_ions_coefficients',
#   'data.perovskite.composition_inorganic',
#   'data.perovskite.composition_leadfree',
#   'data.perovskite.composition_long_form',
#   'data.perovskite.composition_perovskite_ABC3_structure',
#   'data.perovskite.composition_perovskite_inspired_structure',
#   'data.perovskite.composition_short_form',
#   'data.perovskite.dimension_0D',
#   'data.perovskite.dimension_2D',
#   'data.perovskite.dimension_2D3D_mixture',
#   'data.perovskite.dimension_3D',
#   'data.perovskite.dimension_3D_with_2D_capping_layer',
#   'data.perovskite.dimension_list_of_layers',
#   'data.perovskite.single_crystal',
#   'data.perovskite.storage_atmosphere',
#   'data.perovskite.storage_time_until_next_deposition_step',
#   'data.perovskite_deposition',
#   'data.perovskite_deposition.aggregation_state_of_reactants',
#   'data.perovskite_deposition.number_of_deposition_steps',
#   'data.perovskite_deposition.procedure',
#   'data.perovskite_deposition.quenching_induced_crystallisation',
#   'data.perovskite_deposition.quenching_media',
#   'data.perovskite_deposition.quenching_media_volume',
#   'data.perovskite_deposition.reaction_solutions_age',
#   'data.perovskite_deposition.reaction_solutions_compounds_purity',
#   'data.perovskite_deposition.reaction_solutions_compounds_supplier',
#   'data.perovskite_deposition.reaction_solutions_temperature',
#   'data.perovskite_deposition.reaction_solutions_volumes',
#   'data.perovskite_deposition.solvent_annealing',
#   'data.perovskite_deposition.solvent_annealing_solvent_atmosphere',
#   'data.perovskite_deposition.solvent_annealing_temperature',
#   'data.perovskite_deposition.solvent_annealing_time',
#   'data.perovskite_deposition.solvents',
#   'data.perovskite_deposition.solvents_mixing_ratios',
#   'data.perovskite_deposition.solvents_purity',
#   'data.perovskite_deposition.solvents_supplier',
#   'data.perovskite_deposition.substrate_temperature',
#   'data.perovskite_deposition.synthesis_atmosphere',
#   'data.perovskite_deposition.thermal_annealing_atmosphere',
#   'data.perovskite_deposition.thermal_annealing_temperature',
#   'data.perovskite_deposition.thermal_annealing_time',
#   'data.ref',
#   'data.ref.DOI_number',
#   'data.ref.ID',
#   'data.ref.ID_temp',
#   'data.ref.data_entered_by_author',
#   'data.ref.journal',
#   'data.ref.lead_author',
#   'data.ref.name_of_person_entering_the_data',
#   'data.ref.original_filename_data_upload',
#   'data.ref.part_of_initial_dataset',
#   'data.ref.publication_date',
#   'data.stabilised',
#   'data.stabilised.performance_measured',
#   'data.stability',
#   'data.stability.PCE_burn_in_observed',
#   'data.stability.atmosphere',
#   'data.stability.average_over_n_number_of_cells',
#   'data.stability.flexible_cell_number_of_bending_cycles',
#   'data.stability.light_UV_filter',
#   'data.stability.light_cycling_times',
#   'data.stability.light_wavelength_range',
#   'data.stability.measured',
#   'data.stability.periodic_JV_measurements',
#   'data.stability.periodic_JV_measurements_time_between_jv',
#   'data.stability.potential_bias_range',
#   'data.stability.relative_humidity_range',
#   'data.stability.temperature_cycling_times',
#   'data.stability.temperature_range',
#   'data.substrate',
#   'data.substrate.deposition_procedure',
#   'data.substrate.stack_sequence',
#   'metadata',
#   'metadata.coauthors',
#   'metadata.datasets',
#   'metadata.embargo_length',
#   'metadata.entry_coauthors',
#   'metadata.entry_create_time',
#   'metadata.entry_hash',
#   'metadata.entry_id',
#   'metadata.entry_name',
#   'metadata.entry_timestamp',
#   'metadata.entry_timestamp.timestamp',
#   'metadata.entry_timestamp.token',
#   'metadata.entry_timestamp.token_seed',
#   'metadata.entry_timestamp.tsa_server',
#   'metadata.entry_type',
#   'metadata.external_db',
#   'metadata.files',
#   'metadata.last_edit_time',
#   'metadata.last_processing_time',
#   'metadata.license',
#   'metadata.main_author',
#   'metadata.mainfile',
#   'metadata.nomad_commit',
#   'metadata.nomad_version',
#   'metadata.parser_name',
#   'metadata.processed',
#   'metadata.processing_errors',
#   'metadata.publish_time',
#   'metadata.published',
#   'metadata.quantities',
#   'metadata.references',
#   'metadata.reviewers',
#   'metadata.section_defs',
#   'metadata.section_defs.definition_id',
#   'metadata.section_defs.definition_qualified_name',
#   'metadata.section_defs.used_directly',
#   'metadata.sections',
#   'metadata.upload_create_time',
#   'metadata.upload_id',
#   'metadata.upload_name',
#   'metadata.with_embargo',
#   'results',
#   'results.material',
#   'results.material.chemical_formula_anonymous',
#   'results.material.chemical_formula_descriptive',
#   'results.material.chemical_formula_hill',
#   'results.material.chemical_formula_iupac',
#   'results.material.chemical_formula_reduced',
#   'results.material.elements',
#   'results.material.functional_type',
#   'results.material.structural_type',
#   'results.material.symmetry',
#   'results.material.symmetry.structure_name',
#   'results.properties',
#   'results.properties.available_properties',
#   'results.properties.optoelectronic',
#   'results.properties.optoelectronic.solar_cell',
#   'results.properties.optoelectronic.solar_cell.absorber',
#   'results.properties.optoelectronic.solar_cell.absorber_fabrication',
#   'results.properties.optoelectronic.solar_cell.back_contact',
#   'results.properties.optoelectronic.solar_cell.device_architecture',
#   'results.properties.optoelectronic.solar_cell.device_area',
#   'results.properties.optoelectronic.solar_cell.device_stack',
#   'results.properties.optoelectronic.solar_cell.efficiency',
#   'results.properties.optoelectronic.solar_cell.electron_transport_layer',
#   'results.properties.optoelectronic.solar_cell.fill_factor',
#   'results.properties.optoelectronic.solar_cell.hole_transport_layer',
#   'results.properties.optoelectronic.solar_cell.illumination_intensity',
#   'results.properties.optoelectronic.solar_cell.open_circuit_voltage',
#   'results.properties.optoelectronic.solar_cell.short_circuit_current_density',
#   'results.properties.optoelectronic.solar_cell.substrate'],
#  'datasets': [{'dataset_type': 'DatasetType.owned',
#    'dataset_id': 'bVE6OHGxSxag_i8Y0NC4wQ',
#    'dataset_create_time': '2022-09-07T13:19:05.642000+00:00',
#    'dataset_name': 'Perovskite Solar Cell Database Project',
#    'dataset_modified_time': '2022-09-07T13:19:05.642000+00:00'}],
#  'n_quantities': 299,
#  'nomad_version': '1.1.8.dev64+gf1dbf0da4',
#  'upload_create_time': '2022-09-07T08:27:02.161000+00:00',
#  'nomad_commit': '',
#  'publish_time': '2022-09-07T14:46:44.159000+00:00',
#  'section_defs': [{'used_directly': True,
#    'definition_id': '7047cbff9980abff17cce4b1b6b0d1c783505b7f',
#    'definition_qualified_name': 'nomad.datamodel.data.ArchiveSection'},
#   {'used_directly': True,
#    'definition_id': '538f52fd8d52b29372066f878319c6aeb03b74d2',
#    'definition_qualified_name': 'nomad.datamodel.data.EntryData'},
#   {'used_directly': True,
#    'definition_id': '55ef8a0f9a0ce7a75d33a4a33a7144565dc1faa4',
#    'definition_qualified_name': 'nomad.datamodel.datamodel.EntryArchive'},
#   {'used_directly': True,
#    'definition_id': 'c1433047212d95b5607397e0b759bb1508abb19b',
#    'definition_qualified_name': 'nomad.datamodel.datamodel.EntryMetadata'},
#   {'used_directly': True,
#    'definition_id': '265ae33dbc9ace82b50260c1050d30c59ef9cb3c',
#    'definition_qualified_name': 'nomad.datamodel.datamodel.RFC3161Timestamp'},
#   {'used_directly': True,
#    'definition_id': 'c492a9182fddad95ef40700b778ffda47343db83',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'used_directly': True,
#    'definition_id': 'b3200a34ad943b72e9e725066d62473f1744c627',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'used_directly': True,
#    'definition_id': 'bbb4bc39d30ddbd96d1242da0ac0fe38d4575d7c',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Cell'},
#   {'used_directly': True,
#    'definition_id': '5b94d5cc923ad93479239c973537fe19225ca931',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.EQE'},
#   {'used_directly': True,
#    'definition_id': '162d2971e38e2293c672b38f7f2083a722bee863',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'used_directly': True,
#    'definition_id': '13d38144e18cec94e4ec8afb6d415c1021fa1e5e',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Encapsulation'},
#   {'used_directly': True,
#    'definition_id': '00f49de9a3b15f361f9299641fd239e9bda4c12b',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'used_directly': True,
#    'definition_id': 'd77c29c7e9a7bc5265b2799df180c7b536e76145',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'used_directly': True,
#    'definition_id': '22ab6ccd8b50dc5b7c27332225e5a6f203ba39d7',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Module'},
#   {'used_directly': True,
#    'definition_id': 'e3f6cf1feae15bdfed09acad351a30dcc615169d',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Outdoor'},
#   {'used_directly': True,
#    'definition_id': '650eca3c6899ef4b2b46cc879826c763cee42e98',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'used_directly': True,
#    'definition_id': 'f993a775b35651b36450629971b803df94a26390',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'used_directly': True,
#    'definition_id': '0293ef933deb6058bc57eae7180b05f74b0d0493',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteSolarCell'},
#   {'used_directly': True,
#    'definition_id': '85fed67ae23a988ab785ab1e9162d2fd153e419a',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Ref'},
#   {'used_directly': True,
#    'definition_id': '73143edb81736c20d451365285b26e46476989dd',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stabilised'},
#   {'used_directly': True,
#    'definition_id': 'ee172c5e311cda7f87b61d8a6c7cf011ed56662d',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability'},
#   {'used_directly': True,
#    'definition_id': '2aabda187621b3218bcb1a1bb1dcf7987b767bc0',
#    'definition_qualified_name': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Substrate'},
#   {'used_directly': True,
#    'definition_id': '15f0641496953318113f1e330002def5c0a9687d',
#    'definition_qualified_name': 'nomad.datamodel.results.Material'},
#   {'used_directly': True,
#    'definition_id': 'f7cf907b8844bd8dba3b51970f8caa5e525944eb',
#    'definition_qualified_name': 'nomad.datamodel.results.OptoelectronicProperties'},
#   {'used_directly': True,
#    'definition_id': 'bd968238cc0b1918b9dcf488effbd69cb2a35fcc',
#    'definition_qualified_name': 'nomad.datamodel.results.Properties'},
#   {'used_directly': True,
#    'definition_id': 'e59ffbba5896290dbf47c537c8225f5f38cc387e',
#    'definition_qualified_name': 'nomad.datamodel.results.Results'},
#   {'used_directly': True,
#    'definition_id': '07a7e7f7d21c6565fe085633cb5455c8b47a5a8c',
#    'definition_qualified_name': 'nomad.datamodel.results.SolarCell'},
#   {'used_directly': True,
#    'definition_id': 'a4790a3a127cec620ba9bb582a8d6a717e147fa2',
#    'definition_qualified_name': 'nomad.datamodel.results.Symmetry'}],
#  'processing_errors': [],
#  'results': {'material': {'symmetry': {'structure_name': 'perovskite'},
#    'functional_type': ['semiconductor', 'solar cell'],
#    'elements': ['C', 'Cl', 'H', 'I', 'S', 'Sn'],
#    'elements_exclusive': 'C Cl H I S Sn',
#    'chemical_formula_anonymous': 'A18B6C4D2E2F',
#    'structural_type': '2D',
#    'chemical_formula_reduced': 'C6Cl2H18I4S2Sn',
#    'n_elements': 6,
#    'chemical_formula_descriptive': '((CH3)3S)2SnCl2I4',
#    'chemical_formula_hill': 'C6H18Cl2I4S2Sn',
#    'chemical_formula_iupac': 'SnC6H18S2I4Cl2'},
#   'properties': {'optoelectronic': {'solar_cell': {'absorber_fabrication': ['Drop-infiltration'],
#      'efficiency': 2.95,
#      'device_stack': ['SLG',
#       'FTO',
#       'TiO2-mp',
#       'Z907',
#       'Perovskite',
#       'Pt',
#       'SLG',
#       'FTO'],
#      'short_circuit_current_density': 86.6,
#      'hole_transport_layer': ['none'],
#      'fill_factor': 0.58,
#      'illumination_intensity': 1000.0,
#      'electron_transport_layer': ['TiO2-mp', 'Z907'],
#      'device_area': 1.52e-05,
#      'back_contact': ['Pt', 'FTO', 'SLG'],
#      'absorber': ['((CH3)3S)SnClI'],
#      'open_circuit_voltage': 0.59,
#      'substrate': ['SLG', 'FTO'],
#      'device_architecture': 'nip'}},
#    'available_properties': ['solar_cell']}},
#  'entry_name': '34490.archive.json',
#  'last_processing_time': '2023-03-07T13:00:26.588000+00:00',
#  'parser_name': 'parsers/archive',
#  'searchable_quantities': [{'text_value': 'Weiwei Zuo',
#    'path': 'data.ref.name_of_person_entering_the_data',
#    'quantity_name': 'name_of_person_entering_the_data',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Ref'},
#   {'text_value': '10.1016/j.matchemphys.2019.122310',
#    'path': 'data.ref.DOI_number',
#    'quantity_name': 'DOI_number',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Ref'},
#   {'text_value': 'Elsenety et al.',
#    'path': 'data.ref.lead_author',
#    'quantity_name': 'lead_author',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Ref'},
#   {'path': 'data.ref.publication_date',
#    'date_value': '2019-10-11T00:00:00+00:00',
#    'quantity_name': 'publication_date',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Ref'},
#   {'text_value': 'Materials Chemistry and Physics',
#    'path': 'data.ref.journal',
#    'quantity_name': 'journal',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Ref'},
#   {'text_value': 'Historic dataset on 2020 11 22_v7.xlsx',
#    'path': 'data.ref.original_filename_data_upload',
#    'quantity_name': 'original_filename_data_upload',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Ref'},
#   {'text_value': 'SLG | FTO | TiO2-mp | Z907 | Perovskite | Pt | SLG | FTO',
#    'path': 'data.cell.stack_sequence',
#    'quantity_name': 'stack_sequence',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Cell'},
#   {'path': 'data.cell.area_measured',
#    'quantity_name': 'area_measured',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Cell',
#    'double_value': 0.152},
#   {'text_value': 'nip',
#    'path': 'data.cell.architecture',
#    'quantity_name': 'architecture',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Cell'},
#   {'text_value': 'nan; nan',
#    'path': 'data.cell.semitransparent_wavelength_range',
#    'quantity_name': 'semitransparent_wavelength_range',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Cell'},
#   {'text_value': 'SLG | FTO',
#    'path': 'data.substrate.stack_sequence',
#    'quantity_name': 'stack_sequence',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Substrate'},
#   {'text_value': 'Unknown',
#    'path': 'data.substrate.deposition_procedure',
#    'quantity_name': 'deposition_procedure',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Substrate'},
#   {'text_value': 'TiO2-mp | Z907',
#    'path': 'data.etl.stack_sequence',
#    'quantity_name': 'stack_sequence',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': '12000.0 | nan',
#    'path': 'data.etl.thickness',
#    'quantity_name': 'thickness',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.additives_compounds',
#    'quantity_name': 'additives_compounds',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Doctor blading | Dipp-coating',
#    'path': 'data.etl.deposition_procedure',
#    'quantity_name': 'deposition_procedure',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_aggregation_state_of_reactants',
#    'quantity_name': 'deposition_aggregation_state_of_reactants',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_synthesis_atmosphere',
#    'quantity_name': 'deposition_synthesis_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_solvents',
#    'quantity_name': 'deposition_solvents',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_solvents_supplier',
#    'quantity_name': 'deposition_solvents_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_solvents_purity',
#    'quantity_name': 'deposition_solvents_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_reaction_solutions_compounds_supplier',
#    'quantity_name': 'deposition_reaction_solutions_compounds_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_reaction_solutions_compounds_purity',
#    'quantity_name': 'deposition_reaction_solutions_compounds_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_reaction_solutions_volumes',
#    'quantity_name': 'deposition_reaction_solutions_volumes',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_reaction_solutions_age',
#    'quantity_name': 'deposition_reaction_solutions_age',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_reaction_solutions_temperature',
#    'quantity_name': 'deposition_reaction_solutions_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_substrate_temperature',
#    'quantity_name': 'deposition_substrate_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_thermal_annealing_temperature',
#    'quantity_name': 'deposition_thermal_annealing_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_thermal_annealing_time',
#    'quantity_name': 'deposition_thermal_annealing_time',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.deposition_thermal_annealing_atmosphere',
#    'quantity_name': 'deposition_thermal_annealing_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': 'Unknown',
#    'path': 'data.etl.storage_atmosphere',
#    'quantity_name': 'storage_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL'},
#   {'text_value': '2.0',
#    'path': 'data.perovskite.dimension_list_of_layers',
#    'quantity_name': 'dimension_list_of_layers',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': '((CH3)3S)',
#    'path': 'data.perovskite.composition_a_ions',
#    'quantity_name': 'composition_a_ions',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': '2',
#    'path': 'data.perovskite.composition_a_ions_coefficients',
#    'quantity_name': 'composition_a_ions_coefficients',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': 'Sn',
#    'path': 'data.perovskite.composition_b_ions',
#    'quantity_name': 'composition_b_ions',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': '1',
#    'path': 'data.perovskite.composition_b_ions_coefficients',
#    'quantity_name': 'composition_b_ions_coefficients',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': 'Cl; I',
#    'path': 'data.perovskite.composition_c_ions',
#    'quantity_name': 'composition_c_ions',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': '2; 4',
#    'path': 'data.perovskite.composition_c_ions_coefficients',
#    'quantity_name': 'composition_c_ions_coefficients',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': '((CH3)3S)SnClI',
#    'path': 'data.perovskite.composition_short_form',
#    'quantity_name': 'composition_short_form',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': '((CH3)3S)2SnCl2I4',
#    'path': 'data.perovskite.composition_long_form',
#    'quantity_name': 'composition_long_form',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': 'Li-TFSI; TBP',
#    'path': 'data.perovskite.additives_compounds',
#    'quantity_name': 'additives_compounds',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'path': 'data.perovskite.band_gap_graded',
#    'quantity_name': 'band_gap_graded',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite',
#    'long_value': 0},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite.storage_time_until_next_deposition_step',
#    'quantity_name': 'storage_time_until_next_deposition_step',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite.storage_atmosphere',
#    'quantity_name': 'storage_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite'},
#   {'text_value': 'Drop-infiltration',
#    'path': 'data.perovskite_deposition.procedure',
#    'quantity_name': 'procedure',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Liquid',
#    'path': 'data.perovskite_deposition.aggregation_state_of_reactants',
#    'quantity_name': 'aggregation_state_of_reactants',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'N2',
#    'path': 'data.perovskite_deposition.synthesis_atmosphere',
#    'quantity_name': 'synthesis_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'DMF',
#    'path': 'data.perovskite_deposition.solvents',
#    'quantity_name': 'solvents',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': '1',
#    'path': 'data.perovskite_deposition.solvents_mixing_ratios',
#    'quantity_name': 'solvents_mixing_ratios',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.solvents_supplier',
#    'quantity_name': 'solvents_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.solvents_purity',
#    'quantity_name': 'solvents_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.reaction_solutions_compounds_supplier',
#    'quantity_name': 'reaction_solutions_compounds_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.reaction_solutions_compounds_purity',
#    'quantity_name': 'reaction_solutions_compounds_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.reaction_solutions_volumes',
#    'quantity_name': 'reaction_solutions_volumes',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.reaction_solutions_age',
#    'quantity_name': 'reaction_solutions_age',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.reaction_solutions_temperature',
#    'quantity_name': 'reaction_solutions_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.substrate_temperature',
#    'quantity_name': 'substrate_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.quenching_media',
#    'quantity_name': 'quenching_media',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.quenching_media_volume',
#    'quantity_name': 'quenching_media_volume',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.thermal_annealing_temperature',
#    'quantity_name': 'thermal_annealing_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.thermal_annealing_time',
#    'quantity_name': 'thermal_annealing_time',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.thermal_annealing_atmosphere',
#    'quantity_name': 'thermal_annealing_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.solvent_annealing_solvent_atmosphere',
#    'quantity_name': 'solvent_annealing_solvent_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.solvent_annealing_time',
#    'quantity_name': 'solvent_annealing_time',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'Unknown',
#    'path': 'data.perovskite_deposition.solvent_annealing_temperature',
#    'quantity_name': 'solvent_annealing_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition'},
#   {'text_value': 'none',
#    'path': 'data.htl.stack_sequence',
#    'quantity_name': 'stack_sequence',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_procedure',
#    'quantity_name': 'deposition_procedure',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_aggregation_state_of_reactants',
#    'quantity_name': 'deposition_aggregation_state_of_reactants',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_synthesis_atmosphere',
#    'quantity_name': 'deposition_synthesis_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_solvents',
#    'quantity_name': 'deposition_solvents',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_solvents_supplier',
#    'quantity_name': 'deposition_solvents_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_solvents_purity',
#    'quantity_name': 'deposition_solvents_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_reaction_solutions_compounds_supplier',
#    'quantity_name': 'deposition_reaction_solutions_compounds_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_reaction_solutions_compounds_purity',
#    'quantity_name': 'deposition_reaction_solutions_compounds_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_reaction_solutions_volumes',
#    'quantity_name': 'deposition_reaction_solutions_volumes',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_reaction_solutions_age',
#    'quantity_name': 'deposition_reaction_solutions_age',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_reaction_solutions_temperature',
#    'quantity_name': 'deposition_reaction_solutions_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_substrate_temperature',
#    'quantity_name': 'deposition_substrate_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_thermal_annealing_temperature',
#    'quantity_name': 'deposition_thermal_annealing_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_thermal_annealing_time',
#    'quantity_name': 'deposition_thermal_annealing_time',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.deposition_thermal_annealing_atmosphere',
#    'quantity_name': 'deposition_thermal_annealing_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.storage_time_until_next_deposition_step',
#    'quantity_name': 'storage_time_until_next_deposition_step',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Unknown',
#    'path': 'data.htl.storage_atmosphere',
#    'quantity_name': 'storage_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL'},
#   {'text_value': 'Pt | FTO | SLG',
#    'path': 'data.backcontact.stack_sequence',
#    'quantity_name': 'stack_sequence',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Sandwiching',
#    'path': 'data.backcontact.deposition_procedure',
#    'quantity_name': 'deposition_procedure',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_aggregation_state_of_reactants',
#    'quantity_name': 'deposition_aggregation_state_of_reactants',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_synthesis_atmosphere',
#    'quantity_name': 'deposition_synthesis_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_solvents',
#    'quantity_name': 'deposition_solvents',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_solvents_supplier',
#    'quantity_name': 'deposition_solvents_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_solvents_purity',
#    'quantity_name': 'deposition_solvents_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_reaction_solutions_compounds_supplier',
#    'quantity_name': 'deposition_reaction_solutions_compounds_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_reaction_solutions_compounds_purity',
#    'quantity_name': 'deposition_reaction_solutions_compounds_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_reaction_solutions_volumes',
#    'quantity_name': 'deposition_reaction_solutions_volumes',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_reaction_solutions_age',
#    'quantity_name': 'deposition_reaction_solutions_age',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_reaction_solutions_temperature',
#    'quantity_name': 'deposition_reaction_solutions_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_substrate_temperature',
#    'quantity_name': 'deposition_substrate_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_thermal_annealing_temperature',
#    'quantity_name': 'deposition_thermal_annealing_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_thermal_annealing_time',
#    'quantity_name': 'deposition_thermal_annealing_time',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.deposition_thermal_annealing_atmosphere',
#    'quantity_name': 'deposition_thermal_annealing_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.storage_time_until_next_deposition_step',
#    'quantity_name': 'storage_time_until_next_deposition_step',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.backcontact.storage_atmosphere',
#    'quantity_name': 'storage_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_stack_sequence',
#    'quantity_name': 'lay_front_stack_sequence',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_procedure',
#    'quantity_name': 'lay_front_deposition_procedure',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_aggregation_state_of_reactants',
#    'quantity_name': 'lay_front_deposition_aggregation_state_of_reactants',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_synthesis_atmosphere',
#    'quantity_name': 'lay_front_deposition_synthesis_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_solvents',
#    'quantity_name': 'lay_front_deposition_solvents',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_solvents_supplier',
#    'quantity_name': 'lay_front_deposition_solvents_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_solvents_purity',
#    'quantity_name': 'lay_front_deposition_solvents_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_reaction_solutions_compounds_supplier',
#    'quantity_name': 'lay_front_deposition_reaction_solutions_compounds_supplier',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_reaction_solutions_compounds_purity',
#    'quantity_name': 'lay_front_deposition_reaction_solutions_compounds_purity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_reaction_solutions_volumes',
#    'quantity_name': 'lay_front_deposition_reaction_solutions_volumes',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_reaction_solutions_age',
#    'quantity_name': 'lay_front_deposition_reaction_solutions_age',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_reaction_solutions_temperature',
#    'quantity_name': 'lay_front_deposition_reaction_solutions_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_substrate_temperature',
#    'quantity_name': 'lay_front_deposition_substrate_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_thermal_annealing_temperature',
#    'quantity_name': 'lay_front_deposition_thermal_annealing_temperature',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_front_deposition_thermal_annealing_time',
# ...
#   {'text_value': 'Unknown',
#    'path': 'data.add.lay_back_storage_atmosphere',
#    'quantity_name': 'lay_back_storage_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add'},
#   {'text_value': 'Unknown',
#    'path': 'data.encapsulation.stack_sequence',
#    'quantity_name': 'stack_sequence',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Encapsulation'},
#   {'text_value': 'Unknown',
#    'path': 'data.encapsulation.edge_sealing_materials',
#    'quantity_name': 'edge_sealing_materials',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Encapsulation'},
#   {'text_value': 'Unknown',
#    'path': 'data.encapsulation.atmosphere_for_encapsulation',
#    'quantity_name': 'atmosphere_for_encapsulation',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Encapsulation'},
#   {'text_value': 'Unknown',
#    'path': 'data.jv.storage_age_of_cell',
#    'quantity_name': 'storage_age_of_cell',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'text_value': 'Unknown',
#    'path': 'data.jv.storage_atmosphere',
#    'quantity_name': 'storage_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'text_value': 'Air',
#    'path': 'data.jv.test_atmosphere',
#    'quantity_name': 'test_atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'path': 'data.jv.light_intensity',
#    'quantity_name': 'light_intensity',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#    'double_value': 100.0},
#   {'text_value': 'AM 1.5',
#    'path': 'data.jv.light_spectra',
#    'quantity_name': 'light_spectra',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'text_value': 'nan; nan',
#    'path': 'data.jv.light_wavelength_range',
#    'quantity_name': 'light_wavelength_range',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'path': 'data.jv.reverse_scan_Voc',
#    'quantity_name': 'reverse_scan_Voc',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#    'double_value': 0.59},
#   {'path': 'data.jv.reverse_scan_Jsc',
#    'quantity_name': 'reverse_scan_Jsc',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#    'double_value': 8.66},
#   {'path': 'data.jv.reverse_scan_FF',
#    'quantity_name': 'reverse_scan_FF',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#    'double_value': 0.58},
#   {'path': 'data.jv.reverse_scan_PCE',
#    'quantity_name': 'reverse_scan_PCE',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#    'double_value': 2.95},
#   {'path': 'data.jv.default_Voc',
#    'quantity_name': 'default_Voc',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#    'double_value': 0.59},
#   {'path': 'data.jv.default_Jsc',
#    'quantity_name': 'default_Jsc',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#    'double_value': 8.66},
#   {'path': 'data.jv.default_FF',
#    'quantity_name': 'default_FF',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#    'double_value': 0.58},
#   {'path': 'data.jv.default_PCE',
#    'quantity_name': 'default_PCE',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#    'double_value': 2.95},
#   {'text_value': 'Reversed',
#    'path': 'data.jv.default_Voc_scan_direction',
#    'quantity_name': 'default_Voc_scan_direction',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'text_value': 'Reversed',
#    'path': 'data.jv.default_Jsc_scan_direction',
#    'quantity_name': 'default_Jsc_scan_direction',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'text_value': 'Reversed',
#    'path': 'data.jv.default_FF_scan_direction',
#    'quantity_name': 'default_FF_scan_direction',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'text_value': 'Reversed',
#    'path': 'data.jv.default_PCE_scan_direction',
#    'quantity_name': 'default_PCE_scan_direction',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV'},
#   {'text_value': 'nan; nan',
#    'path': 'data.stability.light_wavelength_range',
#    'quantity_name': 'light_wavelength_range',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability'},
#   {'text_value': 'Unknown',
#    'path': 'data.stability.light_cycling_times',
#    'quantity_name': 'light_cycling_times',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability'},
#   {'text_value': 'nan; nan',
#    'path': 'data.stability.potential_bias_range',
#    'quantity_name': 'potential_bias_range',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability'},
#   {'text_value': 'nan; nan',
#    'path': 'data.stability.temperature_range',
#    'quantity_name': 'temperature_range',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability'},
#   {'text_value': 'Unknown',
#    'path': 'data.stability.temperature_cycling_times',
#    'quantity_name': 'temperature_cycling_times',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability'},
#   {'text_value': 'Unknown',
#    'path': 'data.stability.atmosphere',
#    'quantity_name': 'atmosphere',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability'},
#   {'text_value': 'nan; nan',
#    'path': 'data.stability.relative_humidity_range',
#    'quantity_name': 'relative_humidity_range',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability'},
#   {'text_value': 'Unknown',
#    'path': 'data.stability.periodic_JV_measurements_time_between_jv',
#    'quantity_name': 'periodic_JV_measurements_time_between_jv',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability'},
#   {'text_value': 'nan; nan',
#    'path': 'data.outdoor.location_coordinates',
#    'quantity_name': 'location_coordinates',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Outdoor'},
#   {'text_value': '0000:00:00:00:00',
#    'path': 'data.outdoor.time_start',
#    'quantity_name': 'time_start',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Outdoor'},
#   {'text_value': '0000:00:00:00:00',
#    'path': 'data.outdoor.time_end',
#    'quantity_name': 'time_end',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Outdoor'},
#   {'text_value': 'nan; nan',
#    'path': 'data.outdoor.potential_bias_range',
#    'quantity_name': 'potential_bias_range',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Outdoor'},
#   {'text_value': 'nan; nan',
#    'path': 'data.outdoor.temperature_range',
#    'quantity_name': 'temperature_range',
#    'section_definition': 'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Outdoor'}],
#  'calc_id': 'ytbcLJsvYHisgbBPtXEswKwLFJzf',
#  'published': True,
#  'writers': [{'user_id': '62314f75-a859-4b3a-ae6d-e9a0f6c1d8cc',
#    'name': 'Pepe Marquez'},
#   {'user_id': '05375d3f-87e5-4266-9ec8-e80bfe2a739d',
#    'name': 'Markus Scheidgen'}],
#  'sections': ['nomad.datamodel.datamodel.EntryArchive',
#   'nomad.datamodel.datamodel.EntryMetadata',
#   'nomad.datamodel.datamodel.RFC3161Timestamp',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Add',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Backcontact',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Cell',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.EQE',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.ETL',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Encapsulation',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.HTL',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.JV',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Module',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Outdoor',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Perovskite',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteDeposition',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.PerovskiteSolarCell',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Ref',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stabilised',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Stability',
#   'nomad.datamodel.metainfo.eln.perovskite_solar_cell_database.Substrate',
#   'nomad.datamodel.results.Material',
#   'nomad.datamodel.results.OptoelectronicProperties',
#   'nomad.datamodel.results.Properties',
#   'nomad.datamodel.results.Results',
#   'nomad.datamodel.results.SolarCell',
#   'nomad.datamodel.results.Symmetry'],
#  'processed': True,
#  'mainfile': 'full_perovskite_database_archive/34490.archive.json',
#  'main_author': {'user_id': '62314f75-a859-4b3a-ae6d-e9a0f6c1d8cc',
#   'name': 'Pepe Marquez'},
#  'viewers': [{'user_id': '62314f75-a859-4b3a-ae6d-e9a0f6c1d8cc',
#    'name': 'Pepe Marquez'},
#   {'user_id': '05375d3f-87e5-4266-9ec8-e80bfe2a739d',
#    'name': 'Markus Scheidgen'}],
#  'entry_create_time': '2022-09-07T08:55:48.661000+00:00',
#  'with_embargo': False,
#  'external_db': 'The Perovskite Database Project',
#  'files': ['full_perovskite_database_archive/34490.archive.json',
#   'full_perovskite_database_archive/1.archive.json',
#   'full_perovskite_database_archive/10.archive.json',
#   'full_perovskite_database_archive/100.archive.json',
#   'full_perovskite_database_archive/1000.archive.json',
#   'full_perovskite_database_archive/10000.archive.json',
#   'full_perovskite_database_archive/10001.archive.json',
#   'full_perovskite_database_archive/10002.archive.json',
#   'full_perovskite_database_archive/10003.archive.json',
#   'full_perovskite_database_archive/10004.archive.json',
#   'full_perovskite_database_archive/10005.archive.json',
#   'full_perovskite_database_archive/10006.archive.json',
#   'full_perovskite_database_archive/10007.archive.json',
#   'full_perovskite_database_archive/10008.archive.json',
#   'full_perovskite_database_archive/10009.archive.json',
#   'full_perovskite_database_archive/1001.archive.json',
#   'full_perovskite_database_archive/10010.archive.json',
#   'full_perovskite_database_archive/10011.archive.json',
#   'full_perovskite_database_archive/10012.archive.json',
#   'full_perovskite_database_archive/10013.archive.json',
#   'full_perovskite_database_archive/10014.archive.json',
#   'full_perovskite_database_archive/10015.archive.json',
#   'full_perovskite_database_archive/10016.archive.json',
#   'full_perovskite_database_archive/10017.archive.json',
#   'full_perovskite_database_archive/10018.archive.json',
#   'full_perovskite_database_archive/10019.archive.json',
#   'full_perovskite_database_archive/1002.archive.json',
#   'full_perovskite_database_archive/10020.archive.json',
#   'full_perovskite_database_archive/10021.archive.json',
#   'full_perovskite_database_archive/10022.archive.json',
#   'full_perovskite_database_archive/10023.archive.json',
#   'full_perovskite_database_archive/10024.archive.json',
#   'full_perovskite_database_archive/10025.archive.json',
#   'full_perovskite_database_archive/10026.archive.json',
#   'full_perovskite_database_archive/10027.archive.json',
#   'full_perovskite_database_archive/10028.archive.json',
#   'full_perovskite_database_archive/10029.archive.json',
#   'full_perovskite_database_archive/1003.archive.json',
#   'full_perovskite_database_archive/10030.archive.json',
#   'full_perovskite_database_archive/10031.archive.json',
#   'full_perovskite_database_archive/10032.archive.json',
#   'full_perovskite_database_archive/10033.archive.json',
#   'full_perovskite_database_archive/10034.archive.json',
#   'full_perovskite_database_archive/10035.archive.json',
#   'full_perovskite_database_archive/10036.archive.json',
#   'full_perovskite_database_archive/10037.archive.json',
#   'full_perovskite_database_archive/10038.archive.json',
#   'full_perovskite_database_archive/10039.archive.json',
#   'full_perovskite_database_archive/1004.archive.json',
#   'full_perovskite_database_archive/10040.archive.json',
#   'full_perovskite_database_archive/10041.archive.json',
#   'full_perovskite_database_archive/10042.archive.json',
#   'full_perovskite_database_archive/10043.archive.json',
#   'full_perovskite_database_archive/10044.archive.json',
#   'full_perovskite_database_archive/10045.archive.json',
#   'full_perovskite_database_archive/10046.archive.json',
#   'full_perovskite_database_archive/10047.archive.json',
#   'full_perovskite_database_archive/10048.archive.json',
#   'full_perovskite_database_archive/10049.archive.json',
#   'full_perovskite_database_archive/1005.archive.json',
#   'full_perovskite_database_archive/10050.archive.json',
#   'full_perovskite_database_archive/10051.archive.json',
#   'full_perovskite_database_archive/10052.archive.json',
#   'full_perovskite_database_archive/10053.archive.json',
#   'full_perovskite_database_archive/10054.archive.json',
#   'full_perovskite_database_archive/10055.archive.json',
#   'full_perovskite_database_archive/10056.archive.json',
#   'full_perovskite_database_archive/10057.archive.json',
#   'full_perovskite_database_archive/10058.archive.json',
#   'full_perovskite_database_archive/10059.archive.json',
#   'full_perovskite_database_archive/1006.archive.json',
#   'full_perovskite_database_archive/10060.archive.json',
#   'full_perovskite_database_archive/10061.archive.json',
#   'full_perovskite_database_archive/10062.archive.json',
#   'full_perovskite_database_archive/10063.archive.json',
#   'full_perovskite_database_archive/10064.archive.json',
#   'full_perovskite_database_archive/10065.archive.json',
#   'full_perovskite_database_archive/10066.archive.json',
#   'full_perovskite_database_archive/10067.archive.json',
#   'full_perovskite_database_archive/10068.archive.json',
#   'full_perovskite_database_archive/10069.archive.json',
#   'full_perovskite_database_archive/1007.archive.json',
#   'full_perovskite_database_archive/10070.archive.json',
#   'full_perovskite_database_archive/10071.archive.json',
#   'full_perovskite_database_archive/10072.archive.json',
#   'full_perovskite_database_archive/10073.archive.json',
#   'full_perovskite_database_archive/10074.archive.json',
#   'full_perovskite_database_archive/10075.archive.json',
#   'full_perovskite_database_archive/10076.archive.json',
#   'full_perovskite_database_archive/10077.archive.json',
#   'full_perovskite_database_archive/10078.archive.json',
#   'full_perovskite_database_archive/10079.archive.json',
#   'full_perovskite_database_archive/1008.archive.json',
#   'full_perovskite_database_archive/10080.archive.json',
#   'full_perovskite_database_archive/10081.archive.json',
#   'full_perovskite_database_archive/10082.archive.json',
#   'full_perovskite_database_archive/10083.archive.json',
#   'full_perovskite_database_archive/10084.archive.json',
#   'full_perovskite_database_archive/10085.archive.json',
#   'full_perovskite_database_archive/10086.archive.json',
#   'full_perovskite_database_archive/10087.archive.json',
#   'full_perovskite_database_archive/10088.archive.json'],
#  'entry_type': 'PerovskiteSolarCell',
#  'entry_id': 'ytbcLJsvYHisgbBPtXEswKwLFJzf',
#  'upload_name': 'Perovskite Solar Cells (The Perovskite Database Project)',
#  'authors': [{'user_id': '62314f75-a859-4b3a-ae6d-e9a0f6c1d8cc',
#    'name': 'Pepe Marquez'},
#   {'user_id': '05375d3f-87e5-4266-9ec8-e80bfe2a739d',
#    'name': 'Markus Scheidgen'}],
#  'license': 'CC BY 4.0'}

# %% [markdown]
# # Pickle the result
# Fetching all those entries took ca. 30 mins, so I pickle them here.

# %%
df_all_ctls = pd.DataFrame({'etl': etl, 'htl': htl})

# %%
import pickle
with open('df_all_ctl.pkl', 'wb') as f:
    pickle.dump(df_all_ctls, f)

# %%
df_all_ctls
# Out:
#                      etl                    htl
# 0         [PCBM-60, LiF]  [PEDOT:PSS, PDPP-DTT]
# 1       [PCBM-60, Bphen]            [PEDOT:PSS]
# 2      [TiO2-c, TiO2-mp]                 [none]
# 3       [PCBM-60, Bphen]            [PEDOT:PSS]
# 4               [TiO2-c]           [MeO-PheDOT]
# ...                  ...                    ...
# 43114  [TiO2-c, TiO2-mp]         [Spiro-MeOTAD]
# 43115    [ZnO-c, ZnO-nw]         [Spiro-MeOTAD]
# 43116     [PCBM-60, BCP]            [PEDOT:PSS]
# 43117           [SnO2-c]         [Spiro-MeOTAD]
# 43118     [PCBM-60, BCP]            [PEDOT:PSS]
#
# [43119 rows x 2 columns]

# %% [markdown]
# # Only get a couple entries for experimentation
# In order to have less entries for experimentation, we fetch only entries with
# Sulfur in them, which limits the 43119 to about 1000.

# %%
# Function to extract values from the downloaded entries
def extract_values(entry):
    try:
        htl.append(entry['results']['properties']['optoelectronic']['solar_cell']['hole_transport_layer'])
    except:
        htl.append('None')
    try:
        etl.append(entry['results']['properties']['optoelectronic']['solar_cell']['electron_transport_layer'])
    except:
        etl.append('None')
    try:
        pce.append(entry['results']['properties']['optoelectronic']['solar_cell']['efficiency'])
    except:
        pce.append('None')
    try:
        ref.append(entry['references'])
    except:
        ref.append('None')
    return htl, etl, pce, ref

# %%
# only the results.material.elements:all": ["S"] part was changed

import requests

htl = []
etl = []
pce = []
ref = []
page_after_value = None
base_url = 'https://nomad-lab.eu/prod/v1/api/v1/'

while True:
    data = requests.post(f'{base_url}entries/query', json={
        "owner": "visible",
        "aggregations": {},
        "query": {
            "and": [
                {"results.material.elements:all": ["S"]}, # change was made here
                {"sections:all": ["nomad.datamodel.results.SolarCell"]},
                ]},
        "required": {
            "results":{
                "material": {
                    "chemical_formula_reduced":"*",
                    "structural_type":"*"},
                "properties": {
                   "optoelectronic":{
                      "band_gap":"*",
                      "solar_cell":{
                          "open_circuit_voltage":"*",
                          "short_circuit_current_density":"*",
                          "fill_factor":"*",
                          "efficiency":"*",
                          }}},},
        },
        "pagination": {"page_size": 10,
                       "page_after_value": page_after_value}
        }).json()
    if not data['data']:
        break
    if 'next_page_after_value' not in data['pagination'].keys():
      # make sure to grasp the entries of the last page before breaking
      for entry in data['data']:
        if 'results' not in entry.keys():
          continue
        elif 'chemical_formula_reduced' not in entry['results']['material'].keys():
          continue
        else:
          extract_values(entry)
      break
    page_after_value = data['pagination']['next_page_after_value']

    for entry in data['data']:
      if 'results' not in entry.keys():
        continue
      elif 'chemical_formula_reduced' not in entry['results']['material'].keys():
        continue
      else:
        extract_values(entry)

# %%
df_some_test_ctls = pd.DataFrame({'etl': etl, 'htl': htl, 'pce': pce, 'ref': ref})
# clean up ref so it shows only the reference to the paper
df_some_test_ctls['ref'] = df_some_test_ctls['ref'].apply(lambda x: x[0])

# %%
df_some_test_ctls[0:20]
# Out:
#                   etl             htl    pce  \
# 0      [TiO2-mp, D35]          [none]   1.12
# 1   [TiO2-c, TiO2-mp]  [Spiro-MeOTAD]   0.11
# 2         [C60; PEIE]          [PTAA]   20.7
# 3      [PCBM-60, BCP]         [NiO-c]   0.01
# 4      [PCBM-60, BCP]     [PEDOT:PSS]   None
# 5    [PCBM-60, Bphen]     [PEDOT:PSS]  11.32
# 6      [PCBM-60, BCP]     [PEDOT:PSS]  15.93
# 7   [TiO2-c, TiO2-mp]  [Spiro-MeOTAD]   1.69
# 8      [PCBM-60, BCP]     [PEDOT:PSS]   15.0
# 9      [PCBM-60, BCP]     [PEDOT:PSS]  18.01
# 10  [TiO2-c, TiO2-mp]  [Spiro-MeOTAD]   0.49
# 11     [PCBM-60, BCP]     [PEDOT:PSS]  17.62
# 12     [PCBM-60, BCP]     [PEDOT:PSS]   1.95
# 13     [PCBM-60, BCP]     [PEDOT:PSS]  18.47
# 14         [C60, BCP]     [PEDOT:PSS]  16.53
# 15     [PCBM-60, BCP]     [PEDOT:PSS]   3.46
# 16  [TiO2-c, TiO2-mp]  [Spiro-MeOTAD]   0.67
# 17     [PCBM-60, BCP]     [PEDOT:PSS]  16.18
# 18     [PCBM-60, BCP]     [PEDOT:PSS]  18.47
# 19     [PCBM-60, BCP]     [PEDOT:PSS]  16.92
#
#                                                   ref
# 0   https://doi.org/10.1016/j.matchemphys.2019.122310
# 1                  https://doi.org/10.1039/c8ra00639c
# 2             https://doi.org/10.1126/science.aba3433
# 3           https://doi.org/10.1186/s40580-017-0120-3
# 4                https://doi.org/10.1021/jacs.0c03363
# 5              https://doi.org/10.1002/advs.201900548
# 6              https://doi.org/10.1002/adma.202001470
# 7              https://doi.org/10.1021/acsami.8b15578
# 8                https://doi.org/10.1021/jacs.8b04604
# 9              https://doi.org/10.1002/adma.202001470
# 10         https://doi.org/10.1016/j.poly.2018.01.034
# 11             https://doi.org/10.1002/adma.202001470
# 12               https://doi.org/10.1021/jacs.8b04604
# 13             https://doi.org/10.1002/adma.202001470
# 14           https://doi.org/10.1021/acs.jpcc.1c03213
# 15               https://doi.org/10.1021/jacs.8b04604
# 16                 https://doi.org/10.1039/c8ra00639c
# 17             https://doi.org/10.1002/adma.202001470
# 18             https://doi.org/10.1002/adma.202001470
# 19             https://doi.org/10.1002/adma.202001470

# %%
import pickle
with open('df_some_test_ctls.pkl','wb') as f:
    pickle.dump(df_some_test_ctls, f)
